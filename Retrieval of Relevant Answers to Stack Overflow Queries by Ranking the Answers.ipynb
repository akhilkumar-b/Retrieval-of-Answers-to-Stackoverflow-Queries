# %% [markdown]
# # Retrieval of Relevant Answers to Stack Overflow Queries by Ranking the Answers

# %% [markdown]
# Stack Overflow is the most used Q&A forum by software developers. It acts as a valuable repository for novice programmers by helping them resolve their queries. As per the Stack Overflow survey 2019, almost 97% of developers visited the Stack Overflow website last year. It also states that each month, about 50 million people visit Stack Overflow to learn, share, and build their careers. Although this forum offers numerous advantages for developers, on the flip side there are few drawbacks associated with it. Due to massive collaboration, there exist different forms of the same questions and each question has more than one answer. Many users find it difficult to get relevant answers to their queries. To overcome these difficulties, we aim to study the semantic similarity between questions, and answer choices available in the Stack Overflow system and analyze the most relevant answers to the question searched using a ranking methodology to produce the most appropriate answer set for the users.
#
# We divided this project into three parts,
# 1.	Question Processing
# 2.	Answer Processing
# 3.	Question and Answer Relevance Mapping
#
# Question Processing :
#     In this phase, we compare probe questions with stack overflow question corpus to find most similar questions in the corpus.
# Answer Processing:
#     In this phase, associated answers for selected questions are filters and grouped together to form various answer clusters.
# Question and Answer Mapping:
#     Each answer clusters are compared to search questions using cosine similarity to check relevance between question and answers.

# %% [markdown]
# ## Question Processing

# %% [markdown]
# ### Data Extraction

# %%
import pandas as pd
import warnings

# Ignore warnings
warnings.filterwarnings('ignore')
quest = pd.read_csv("./Questions.csv", encoding='latin-1')
quest.head()
# Out:
#     Id  OwnerUserId          CreationDate  Score  \
# 0  469        147.0  2008-08-02T15:11:16Z     21
# 1  502        147.0  2008-08-02T17:01:58Z     27
# 2  535        154.0  2008-08-02T18:43:54Z     40
# 3  594        116.0  2008-08-03T01:15:08Z     25
# 4  683        199.0  2008-08-03T13:19:16Z     28
#
#                                                Title  \
# 0  How can I find the full path to a font from it...
# 1            Get a preview JPEG of a PDF on Windows?
# 2  Continuous Integration System for a Python Cod...
# 3     cx_Oracle: How do I iterate over a result set?
# 4  Using 'in' to match an attribute of Python obj...
#
#                                                 Body
# 0  <p>I am using the Photoshop's javascript API t...
# 1  <p>I have a cross-platform (Python) applicatio...
# 2  <p>I'm starting work on a hobby project with a...
# 3  <p>There are several ways to iterate over a re...
# 4  <p>I don't remember whether I was dreaming or ...

# %% [markdown]
# **DATA PREPROCESSING**

# %%
#Filtering WH questions 
Wh_df = quest[quest.Title.str.lower().str.startswith('wh')]
Wh_df.shape
# Out:
# (22722, 6)

# %%
#Converting text to lower cased tokens
#Convert Accented Characters
from gensim.utils import simple_preprocess
def simple_process(question_list):
    for each in question_list:
        yield(simple_preprocess(str(each), deacc = True, max_len = 20, min_len = 1 ))
Question_Title = list(Wh_df['Title'])
Question_data = list(simple_process(Question_Title))

# %%
#Removing stopwords
import nltk.data
stop_words = nltk.corpus.stopwords.words("english")
def rem_stop(question):
    return [word for word in question if word not in stop_words ]

Question_data_filtered1 = [rem_stop(question) for question in Question_data ]
Question_data_filtered = [ ' '.join(question) for question in Question_data ]

# %% [markdown]
# #### Feature Extraction - Word2Vec

# %%
#Loading the stack overflow trained word2vec model
from gensim.models.keyedvectors import KeyedVectors
word_vect = KeyedVectors.load_word2vec_format("./SO_vectors_200.bin", binary=True)

# %%
#Handling unseen words - As data is trained on pretrained model, there exits few words not available in model, removing such words
def unseen_words(question):
    return [word for word in question if word in word_vect.vocab ]
word2vec_list = [unseen_words(question) for question in Question_data_filtered1 ]
word_evec_trans = [word_vect[question] for question in word2vec_list if question != []]
word2vec_list
# Out:
# [['best', 'way', 'distribute', 'python', 'command', 'line', 'tools'],
#  ['best',
#   'way',
#   'grab',
#   'parse',
#   'command',
#   'line',
#   'arguments',
#   'passed',
#   'python',
#   'script'],
#  ['java', 'python', 'garbage', 'collection', 'methods', 'different'],
#  ['python', 'date', 'time', 'conversion', 'seem', 'wrong'],
#  ['best', 'way', 'duplicate', 'fork', 'windows'],
#  ['learn', 'pypy', 'translation', 'function'],
#  ['refactoring', 'tools', 'use', 'python'],
#  ['best', 'way', 'use', 'web', 'services', 'python'],
#  ['python', 'iter', 'mapping', 'return', 'iterkeys', 'instead', 'iteritems'],
#  ['instance', 'variable'],
#  ['double', 'star', 'star', 'python', 'parameters'],
#  ['easiest', 'way', 'read', 'foxpro', 'dbf', 'file', 'python'],
#  ['class', 'methods', 'python'],
#  ['best', 'way', 'return', 'multiple', 'values', 'function', 'python'],
#  ['best', 'way', 'bit', 'field', 'manipulation', 'python'],
#  ['tuple', 'useful'],
#  ['find',
#   'time',
#   'space',
#   'complexity',
#   'built',
#   'sequence',
#   'types',
#   'python'],
#  ['version', 'python', 'use', 'maximum', 'compatibility'],
#  ['advantages',
#   'packaging',
#   'python',
#   'library',
#   'application',
#   'egg',
#   'file'],
#  ['python', 'way', 'suggest', 'check', 'whois', 'database', 'records'],
#  ['simplest', 'way', 'find', 'difference', 'times', 'python'],
#  ['sql',
#   'aggregate',
#   'functions',
#   'much',
#   'slower',
#   'python',
#   'java',
#   'poor',
#   'man',
#   'olap'],
#  ['strategies',
#   'write',
#   'python',
#   'code',
#   'works',
#   'cpython',
#   'jython',
#   'ironpython'],
#  ['difference', 'old', 'style', 'new', 'style', 'classes', 'python'],
#  ['python', 'unit', 'tests', 'go'],
#  ['good', 'way', 'find', 'relative', 'paths', 'google', 'app', 'engine'],
#  ['useful',
#   'mercurial',
#   'hook',
#   'programming',
#   'loosely',
#   'connected',
#   'team'],
#  ['create', 'new', 'app', 'startapp', 'django'],
#  ['might', 'pyglet', 'vertex', 'lists', 'batches', 'slow', 'windows'],
#  ['need', 'explicitly', 'self', 'argument', 'python', 'method'],
#  ['python', 'private', 'methods', 'actually', 'private'],
#  ['faster', 'python', 'webpages', 'php', 'webpages'],
#  ['blazeds',
#   'livecycle',
#   'data',
#   'services',
#   'something',
#   'like',
#   'pyamf',
#   'rubyamf'],
#  ['best', 'way', 'calculate', 'n', 'centroid'],
#  ['len', 'function', 'inherited', 'dictionaries', 'lists', 'python'],
#  ['pros', 'cons', 'various', 'python', 'implementations'],
#  ['easiest', 'non', 'memory', 'intensive', 'way', 'output', 'xml', 'python'],
#  ['difference', 'range', 'xrange', 'functions', 'python', 'x'],
#  ['best', 'solution', 'database', 'connection', 'pooling', 'python'],
#  ['metaclass', 'python'],
#  ['standard', 'way', 'add', 'n', 'seconds', 'datetime', 'time', 'python'],
#  ['someobj', 'better', 'someobj', 'none', 'python'],
#  ['use', 'python', 'generator', 'functions'],
#  ['thread', 'local', 'storage', 'python', 'need'],
#  ['unicode', 'uses', 'str', 'object', 'encoding', 'given'],
#  ['callable', 'python'],
#  ['python', 'equivalents', 'sigrelse', 'functions', 'found', 'c'],
#  ['save',
#   'confirmation',
#   'page',
#   'hooked',
#   'django',
#   'admin',
#   'similar',
#   'delete',
#   'confirmation'],
#  ['fastest', 'way', 'scale', 'display', 'image', 'python'],
#  ['simplest', 'way', 'offer', 'consume', 'web', 'services', 'jython'],
#  ['pythonic', 'factory', 'function', 'module', 'method', 'class', 'creates'],
#  ['simplest', 'way', 'daemonize', 'python', 'script', 'linux'],
#  ['scope', 'imported', 'classes', 'python'],
#  ['name',
#   'python',
#   'module',
#   'formats',
#   'arbitrary',
#   'text',
#   'nicely',
#   'looking',
#   'html'],
#  ['best', 'dispatcher', 'callback', 'library', 'python'],
#  ['wrong', 'snap', 'grid', 'code'],
#  ['python', 'pep', 'strongly', 'recommend', 'spaces', 'tabs', 'indentation'],
#  ['intended',
#   'use',
#   'default',
#   'section',
#   'config',
#   'files',
#   'used',
#   'configparser'],
#  ['easiest',
#   'concise',
#   'way',
#   'make',
#   'selected',
#   'attributes',
#   'instance',
#   'readonly'],
#  ['best', 'way', 'store', 'set', 'data', 'python'],
#  ['best', 'way', 'upgrade', 'django'],
#  ['preferable',
#   'use',
#   'python',
#   'lambda',
#   'functions',
#   'nested',
#   'functions',
#   'def'],
#  ['difference', 'staticmethod', 'classmethod', 'python'],
#  ['results', 'map', 'list', 'comprehension', 'different'],
#  ['limitations',
#   'closures',
#   'python',
#   'compared',
#   'language',
#   'x',
#   'closures'],
#  ['difference'],
#  ['canonical', 'way', 'check', 'type', 'python'],
#  ['preferred',
#   'way',
#   'redirect',
#   'request',
#   'pylons',
#   'without',
#   'losing',
#   'form',
#   'data'],
#  ['best', 'way', 'sample', 'profile', 'pyobjc', 'application'],
#  ['naming', 'convention', 'python', 'variable', 'function', 'names'],
#  ['difference', 'ruby', 'python', 'versions', 'self'],
#  ['best', 'way', 'get', 'list', 'running', 'processes', 'unix', 'python'],
#  ['lambda', 'binding', 'python'],
#  ['best',
#   'way',
#   'remove',
#   'duplicate',
#   'lines',
#   'matching',
#   'regex',
#   'string',
#   'using',
#   'python'],
#  ['best', 'way', 'get', 'divisors', 'number'],
#  ['symmetric', 'cypher', 'use', 'encrypting', 'messages'],
#  ['best', 'way', 'run', 'multiple', 'subprocesses', 'via', 'fork'],
#  ['best',
#   'way',
#   'change',
#   'text',
#   'contained',
#   'xml',
#   'file',
#   'using',
#   'python'],
#  ['difference', 'python', 'search', 'match'],
#  ['problem', 'reduce'],
#  ['use', 'python', 'debugger'],
#  ['need', 'import', 'gain', 'access', 'models'],
#  ['best', 'way', 'open', 'file', 'exclusive', 'access', 'python'],
#  ['property', 'returns', 'regular', 'expression', 'used', 'compile', 'called'],
#  ['best', 'project', 'structure', 'python', 'application'],
#  ['best', 'practices', 'developing', 'consistent', 'libraries'],
#  ['good', 'rules', 'thumb', 'python', 'imports'],
#  ['time', 'complexity', 'popping', 'elements', 'list', 'python'],
#  ['easiest', 'way', 'best', 'tutorials', 'get', 'familiar', 'sqlalchemy'],
#  ['best', 'way', 'escape', 'python', 'strings', 'php'],
#  ['aes', 'library', 'use', 'ruby', 'python'],
#  ['python', 'framework', 'use'],
#  ['recommend', 'high', 'traffic', 'ajax', 'intensive', 'website'],
#  ['attribute', 'references', 'act', 'like', 'python', 'inheritance'],
#  ['receive', 'importerror', 'running', 'one', 'cherrypy', 'tutorials'],
#  ['easy', 'way', 'create', 'trivial', 'one', 'python', 'object'],
#  ['good', 'library', 'manipulate', 'apache', 'config', 'files'],
#  ['difference', 'parent', 'reference', 'property', 'google', 'app', 'engine'],
#  ['purpose', 'colon', 'block', 'python'],
#  ['python', 'decorators', 'rather', 'closures'],
#  ['best',
#   'way',
#   'python',
#   'windows',
#   'execute',
#   'program',
#   'like',
#   'ghostscript',
#   'multiple',
#   'arguments',
#   'spaces',
#   'paths'],
#  ['meaning', 'password', 'python', 'regular', 'expression'],
#  ['urllib', 'actually', 'download', 'file', 'url'],
#  ['better',
#   'implementation',
#   'combinations',
#   'lexicographic',
#   'order',
#   'jagged',
#   'list'],
#  ['win', 'con', 'module', 'python', 'find'],
#  ['yield', 'keyword'],
#  ['best',
#   'python',
#   'soap',
#   'stack',
#   'consuming',
#   'amazon',
#   'web',
#   'services',
#   'wsdl'],
#  ['convention',
#   'distinguish',
#   'object',
#   'methods',
#   'called',
#   'outside',
#   'object',
#   'methods',
#   'called',
#   'subclass'],
#  ['ocaml', 'idiom', 'equivalent', 'python', 'range', 'function'],
#  ['eclipse', 'package', 'download', 'pydev'],
#  ['first', 'class', 'objects'],
#  ['library', 'use', 'write', 'xls', 'linux', 'python'],
#  ['good', 'time', 'use', 'python', 'generators'],
#  ['like', 'django'],
#  ['best',
#   'way',
#   'serve',
#   'static',
#   'web',
#   'pages',
#   'within',
#   'django',
#   'application'],
#  ['django', 'admin', 'application', 'work'],
#  ['python', 'bindings', 'cvs', 'svn'],
#  ['exception',
#   'raise',
#   'bad',
#   'illegal',
#   'argument',
#   'combinations',
#   'python'],
#  ['difference', 'scgi', 'wsgi'],
#  ['exceptions', 'iterable'],
#  ['ruby', 'equivalent', 'python', 'zip', 'builtin'],
#  ['global', 'interpreter', 'lock'],
#  ['mime', 'type', 'return', 'python', 'string'],
#  ['regular', 'expression', 'urlchecker', 'http', 'www', 'google', 'com'],
#  ['difference', 'os', 'popen', 'methods'],
#  ['cross', 'platform', 'way', 'play', 'sound', 'file', 'python'],
#  ['python', 'equivalent', 'static', 'variables', 'inside', 'function'],
#  ['self', 'required'],
#  ['command', 'recognized', 'error', 'occur', 'window', 'populated'],
#  ['python', 'tools', 'use', 'interface', 'website', 'api'],
#  ['best',
#   'way',
#   'transfer',
#   'data',
#   'python',
#   'another',
#   'application',
#   'windows'],
#  ['excel', 'macro', 'work', 'excel', 'called', 'python'],
#  ['simplest', 'way', 'access', 'mssql', 'python', 'ironpython'],
#  ['techniques', 'code', 'generation'],
#  ['regular', 'expression', 'root', 'website', 'django'],
#  ['best',
#   'way',
#   'distribute',
#   'python',
#   'program',
#   'extended',
#   'custom',
#   'c',
#   'modules'],
#  ['partial', 'class'],
#  ['efficient', 'python', 'standard', 'imports', 'contextual', 'imports'],
#  ['xpath', 'work', 'processing', 'xhtml', 'document', 'lxml', 'python'],
#  ['fuse', 'using', 'class', 'supplied', 'file_class'],
#  ['language', 'easiest', 'fastest', 'work', 'xml', 'content'],
#  ['best', 'way', 'find', 'inverse', 'datetime', 'isocalendar'],
#  ['use', 'linux', 'make', 'python', 'program', 'executable'],
#  ['new', 'instances', 'class', 'share', 'members', 'instances'],
#  ['functools', 'wraps'],
#  ['inherit', 'dict', 'exception', 'python'],
#  ['fastest', 'way', 'parse', 'large', 'xml', 'docs', 'python'],
#  ['equivalent', 'map', 'int', 'vector', 'int', 'python'],
#  ['faster', 'python', 'x', 'math', 'sqrt', 'x'],
#  ['python', 'readline', 'module', 'available', 'os', 'x'],
#  ['best', 'way', 'get', 'size', 'folder', 'files', 'inside', 'python'],
#  ['happened', 'python', 'bindings', 'cgal'],
#  ['pygame', 'terms', 'graphics', 'wxpython'],
#  ['efficient',
#   'way',
#   'extracting',
#   'information',
#   'large',
#   'number',
#   'xml',
#   'files',
#   'python'],
#  ['go', 'regarding', 'programming'],
#  ['justify', 'complexity', 'plone'],
#  ['python', 'c', 'extension', 'leaking', 'memory'],
#  ['function', 'set', 'use', 'check', 'two', 'objects', 'different'],
#  ['recommended', 'way', 'use', 'vim', 'folding', 'python', 'code'],
#  ['sqlalchemy', 'equivalent', 'column', 'type', 'money', 'oid', 'postgres'],
#  ['gui',
#   'toolkit',
#   'looks',
#   'best',
#   'native',
#   'laf',
#   'python',
#   'windows',
#   'linux'],
#  ['eclipse',
#   'distribution',
#   'good',
#   'web',
#   'development',
#   'using',
#   'python',
#   'php',
#   'perl'],
#  ['pythonic', 'way', 'avoid', 'default', 'parameters', 'empty', 'lists'],
#  ['best', 'way', 'serialize', 'modelform', 'object', 'django'],
#  ['pythonic', 'way', 'testing', 'inputs', 'well', 'formed', 'numbers'],
#  ['white', 'space', 'important', 'python'],
#  ['object', 'oriented', 'programming', 'computing', 'overhead', 'cost'],
#  ['python', 'real', 'project', 'used', 'example', 'unit', 'test', 'part'],
#  ['esque', 'decorator', 'syntax', 'python', 'mean'],
#  ['tags', 'ivar', 'param', 'type', 'python', 'docstring'],
#  ['steps',
#   'make',
#   'modelform',
#   'work',
#   'manytomany',
#   'relationship',
#   'intermediary',
#   'model',
#   'django'],
#  ['concrete', 'use', 'cases', 'metaclasses', 'python'],
#  ['values',
#   'use',
#   'fastcgi',
#   'maxrequests',
#   'maxspare',
#   'minspare',
#   'maxchildren'],
#  ['python', 'multiline', 'comments'],
#  ['subclass', 'datetime', 'date'],
#  ['cyclic', 'data', 'structure', 'good'],
#  ['ruby', 'rails', 'python', 'central', 'framework'],
#  ['versions', 'python', 'wxpython', 'correspond', 'version', 'osx'],
#  ['character', 'alphanumeric', 'id', 'reddit', 'url'],
#  ['gethostbyaddr', 'gethostname', 'return', 'ipv', 'ip'],
#  ['sign', 'mean', 'django', 'template'],
#  ['sign', 'mean', 'python'],
#  ['python', 'string', 'printable', 'contains', 'unprintable', 'characters'],
#  [],
#  ['pythonic', 'way', 'access', 'c', 'libraries', 'example', 'openssl'],
#  ['easiest',
#   'way',
#   'export',
#   'data',
#   'live',
#   'google',
#   'app',
#   'engine',
#   'application'],
#  ['slug', 'django'],
#  ['managed',
#   'attributes',
#   'work',
#   'class',
#   'attributes',
#   'instance',
#   'attributes',
#   'python'],
#  ['pythonic', 'way', 'count', 'occurrence', 'element', 'list'],
#  ['delete', 'user', 'session'],
#  ['pythonic', 'way', 'iterate', 'list', 'chunks'],
#  ['fastest', 'way', 'draw', 'image', 'discrete', 'pixel', 'values', 'python'],
#  ['alternative', 'execfile', 'python'],
#  ['value_from_datadict', 'method', 'custom', 'form', 'widget', 'return'],
#  ['seeing', 'connection', 'reset', 'peer', 'error'],
#  ['new', 'mp', 'player', 'run', 'old', 'python', 'scripts'],
#  ['best', 'approach', 'implement', 'configuration', 'app', 'django'],
#  ['paramiko', 'hang', 'use', 'loading', 'module'],
#  ['django', 'admin', 'today', 'buttons', 'show', 'safari'],
#  ['best',
#   'way',
#   'specify',
#   'proxy',
#   'username',
#   'password',
#   'https',
#   'connection',
#   'python'],
#  ['get', 'build', 'windows', 'binary', 'mod_wsgi', 'python', 'support'],
#  ['difference', 'encode', 'decode'],
#  ['py'],
#  ['efficient',
#   'way',
#   'access',
#   'sibling',
#   'dictionary',
#   'value',
#   'python',
#   'dict'],
#  ['correct', 'way', 'backup', 'zodb', 'blobs'],
#  ['benefits', 'using', 'python', 'web', 'programming'],
#  ['python', 'message', 'mean'],
#  ['best', 'way', 'handle', 'bad', 'link', 'given', 'beautifulsoup'],
#  ['practical',
#   'difference',
#   'xml',
#   'json',
#   'rss',
#   'atom',
#   'interfacing',
#   'twitter'],
#  ['efficient', 'way', 'share', 'large', 'amounts', 'data', 'python', 'c'],
#  ['best', 'real', 'time', 'plotting', 'widget', 'wxpython'],
#  ['correct',
#   'procedure',
#   'store',
#   'utf',
#   'encoded',
#   'rss',
#   'stream',
#   'sqlite',
#   'using',
#   'python'],
#  ['simple', 'way', 'generate', 'keywords', 'text'],
#  ['specify', 'class', 'using', 'super', 'way', 'get', 'around'],
#  ['python'],
#  ['compile', 'python', 'code'],
#  ['best',
#   'way',
#   'extract',
#   'load',
#   'average',
#   'float',
#   'values',
#   'string',
#   'python'],
#  ['printing', 'image', 'determines', 'large', 'appear', 'page'],
#  ['gtk', 'widget', 'combination', 'use', 'scrollable', 'column', 'widgets'],
#  ['best',
#   'way',
#   'repeatedly',
#   'execute',
#   'function',
#   'every',
#   'x',
#   'seconds',
#   'python'],
#  ['get', 'wiki', 'formatting', 'widget', 'django', 'application'],
#  ['idiomatic', 'python', 'equivalent', 'django', 'regroup', 'template', 'tag'],
#  ['ldap', 'response', 'tuple', 'mean'],
#  ['names', 'dir', 'x', 'valid', 'attribute', 'access'],
#  ['get', 'typeerror', 'multiply', 'sequence', 'non', 'int', 'type', 'float'],
#  ['getting',
#   'following',
#   'error',
#   'python',
#   'importerror',
#   'module',
#   'named',
#   'py'],
#  ['pythonic', 'way', 'make', 'bound', 'method', 'act', 'like', 'function'],
#  ['best',
#   'way',
#   'error',
#   'proof',
#   'foolproof',
#   'parse',
#   'file',
#   'using',
#   'python',
#   'following',
#   'format'],
#  ['python', 'module', 'suitable', 'data', 'manipulation', 'list'],
#  ['good', 'way', 'keep', 'track', 'class', 'instance', 'variables', 'python'],
#  ['best', 'serialization', 'method', 'objects', 'memcached'],
#  ['ironpython', 'faster', 'official', 'python', 'interpreter'],
#  ['django', 'serve', 'files', 'containing', 'space'],
#  ['pyrun_string', 'evaluate', 'bool', 'literals'],
#  ['bad', 'magic', 'number', 'error'],
#  ['best', 'way', 'remove', 'accents', 'python', 'unicode', 'string'],
#  ['cleanest', 'way', 'extract', 'urls', 'string', 'using', 'python'],
#  ['python', 'used', 'read', 'lot', 'reddit'],
#  ['true', 'false', 'capitalized', 'python'],
#  ['python', 'built', 'method', 'acquire', 'speed'],
#  ['concatenation', 'work', 'differently', 'two', 'samples'],
#  ['way', 'create', 'flash', 'animations', 'python'],
#  ['tools', 'used', 'write', 'modular', 'database', 'python'],
#  ['self', 'refer', 'classmethod'],
#  ['mixin', 'useful'],
#  ['keyboardinterrupt', 'working', 'python'],
#  ['causes', 'python', 'socket', 'error'],
#  ['best', 'way', 'make', 'time', 'today', 'yesterday', 'time', 'python'],
#  ['post', 'python', 'code'],
#  ['version', 'turbogears', 'use', 'new', 'project'],
#  ['wrong', 'nested', 'loops', 'python'],
#  ['python',
#   'good',
#   'practice',
#   'importing',
#   'offering',
#   'optional',
#   'features'],
#  ['fastest',
#   'way',
#   'test',
#   'validity',
#   'large',
#   'number',
#   'well',
#   'formed',
#   'urls'],
#  ['good', 'embedded', 'browser', 'pygtk', 'application'],
#  ['reason', 'providing', 'default', 'methods', 'global', 'scope', 'python'],
#  ['python', 'release', 'file', 'handles', 'calling', 'file', 'close'],
#  ['always', 'use', 'psyco', 'python', 'code'],
#  ['pythonic', 'way', 'combine', 'two', 'sequences', 'dictionary'],
#  ['best', 'way', 'print', 'table', 'delimiters', 'python'],
#  ['good',
#   'ways',
#   'upload',
#   'bulk',
#   'csv',
#   'data',
#   'webapp',
#   'using',
#   'django',
#   'python'],
#  ['using', 'random', 'form', 'returns', 'equal', 'chance'],
#  ['python', 'static', 'variables'],
#  ['python', 'function', 'like', 'sum', 'multiplication', 'product'],
#  ['jython', 'behaves', 'inconsistently', 'tested', 'pystone'],
#  ['foo', 'setter', 'python', 'work'],
#  ['appropriate', 'bundle', 'dependencies', 'application'],
#  ['django', 'admin', 'interface', 'used'],
#  ['function', 'matplotlib', 'seems', 'missing', 'examples', 'tutorials'],
#  ['best',
#   'technology',
#   'connecting',
#   'linux',
#   'ms',
#   'sql',
#   'server',
#   'using',
#   'python',
#   'odbc'],
#  ['weakref', 'work', 'bound', 'method'],
#  ['features', 'perfect', 'python', 'debugger'],
#  ['google', 'search', 'return', 'http', 'error'],
#  ['proper', 'way', 'address', 'permissions'],
#  ['search', 'engine', 'used', 'new', 'python', 'documentation'],
#  ['lose',
#   'gain',
#   'switching',
#   'database',
#   'apis',
#   'pywin',
#   'pysqlite',
#   'qsql'],
#  ['good',
#   'strategy',
#   'constructing',
#   'directed',
#   'graph',
#   'game',
#   'map',
#   'python'],
#  ['get', 'wrong', 'results', 'hmac', 'python', 'perl'],
#  ['regular', 'expression', 'returning', 'error', 'python'],
#  ['pypy', 'offer', 'cpython', 'jython', 'ironpython'],
#  ['best',
#   'way',
#   'represent',
#   'schedule',
#   'database',
#   'via',
#   'python',
#   'django'],
#  ['best', 'way', 'find', 'closest', 'matching', 'type', 'existing', 'type'],
#  ['get', 'unexpected', 'behavior', 'python', 'isinstance', 'pickling'],
#  ['compile', 'r', 'match'],
#  ['directly', 'add', 'attributes', 'python', 'object'],
#  ['aware', 'moving', 'asp', 'net', 'python', 'web', 'development'],
#  ['getting', 'invalid', 'syntax', 'easy_install', 'error'],
#  ['signals', 'simply', 'called', 'events'],
#  ['upgrade', 'path', 'python', 'x', 'google', 'app', 'engine', 'applications'],
#  ['difference', 'list', 'tuples'],
#  ['avoid', 'cgi', 'python', 'lamp', 'hosting'],
#  ['best', 'method', 'read', 'double', 'binary', 'file', 'created', 'c'],
#  ['feasibility', 'porting', 'legacy', 'c', 'program', 'python'],
#  ['getting', 'errors', 'installing', 'pysqlite'],
#  ['python', 'frameworks', 'return', 'dictionaries', 'controllers'],
#  ['best', 'way', 'implement', 'nested', 'dictionaries', 'python'],
#  ['different', 'python', 'javascript', 'regular', 'expressions'],
#  ['efficient',
#   'way',
#   'python',
#   'convert',
#   'string',
#   'lowercase',
#   'stripping',
#   'non',
#   'ascii',
#   'alpha',
#   'characters'],
#  ['nearest', 'equivalent', 'beautiful', 'soup', 'ruby'],
#  ['quickest', 'way', 'http', 'get', 'python'],
#  ['elegant',
#   'way',
#   'find',
#   'versions',
#   'packages',
#   'pypi',
#   'package',
#   'index'],
#  ['paste', 'output', 'pythons', 'repl', 'without', 'manual', 'editing'],
#  ['python', 'raw', 'string', 'literals', 'end', 'single', 'backslash'],
#  ['python', 'objects', 'different', 'types', 'ordered', 'type', 'names'],
#  ['version', 'python', 'currently', 'best', 'os', 'x'],
#  ['wx', 'singlechoicedialog', 'subclassing', 'properly'],
#  ['python', 'add', 'global', 'next', 'function'],
#  ['get', 'free', 'gsm', 'libraries', 'components', 'delphi', 'python'],
#  ['correct',
#   'way',
#   'add',
#   'extra',
#   'find',
#   'links',
#   'easy_install',
#   'called',
#   'function'],
#  ['difference', 'dict'],
#  ['errors', 'exceptions', 'need', 'handle', 'urllib', 'request', 'urlopen'],
#  ['good', 'rate', 'limiting', 'algorithm'],
#  ['beautiful', 'soup', 'truncating', 'page'],
#  ['gql', 'query', 'match'],
#  ['signals', 'catch', 'clipboard', 'pasting', 'character', 'insertion', 'gtk'],
#  ['best', 'online', 'tutorial', 'starting', 'spring', 'python'],
#  ['payment',
#   'processing',
#   'frameworks',
#   'like',
#   'activemerchant',
#   'available',
#   'languages'],
#  ['windows', 'give', 'sqlite', 'operationalerror', 'linux'],
#  ['wrong', 'python', 'soappy', 'webservice', 'call'],
#  ['viable', 'database', 'abstraction', 'layers', 'python'],
#  ['difference', 'list', 'list', 'len', 'list'],
#  ['version', 'python', 'added', 'else', 'clause', 'loops'],
#  ['clean', 'pythonic', 'way', 'multiple', 'constructors', 'python'],
#  ['input', 'line', 'long', 'error', 'message'],
#  ['setuptools', 'sometimes', 'delete', 'install', 'exact', 'egg'],
#  ['keyword', 'datefield', 'input_formats', 'recognized', 'django', 'python'],
#  ['standard', 'way', 'op', 'python'],
#  ['subprocess', 'popen', 'always', 'return'],
#  ['best',
#   'way',
#   'internationalize',
#   'python',
#   'app',
#   'multiple',
#   'n',
#   'domains'],
#  ['llvm', 'replacing', 'python', 'vm', 'llvm', 'increasing', 'speeds', 'x'],
#  ['pythonic', 'way', 'share', 'common', 'files', 'multiple', 'projects'],
#  ['best', 'way', 'tell', 'python', 'program', 'anything', 'read', 'stdin'],
#  ['encoding',
#   'need',
#   'display',
#   'gbp',
#   'sign',
#   'pound',
#   'sign',
#   'using',
#   'python',
#   'cygwin',
#   'windows',
#   'xp'],
#  ['best',
#   'way',
#   'pass',
#   'method',
#   'parameters',
#   'another',
#   'method',
#   'python'],
#  ['python',
#   'bayesian',
#   'text',
#   'classification',
#   'modules',
#   'similar',
#   'dbacl'],
#  ['languages',
#   'like',
#   'java',
#   'use',
#   'hierarchical',
#   'package',
#   'names',
#   'python'],
#  ['best', 'way', 'toggle', 'python', 'prints'],
#  ['elegant', 'rephrasing', 'cropping', 'algorithm', 'python'],
#  ['differences', 'json', 'simplejson', 'python', 'modules'],
#  ['maximum', 'number', 'arguments', 'python', 'function'],
#  ['environmental', 'variables', 'set', 'python', 'persist'],
#  ['pyobjc', 'cocoa', 'view', 'class', 'forgetting', 'fields'],
#  ['purpose', 'python', 'inner', 'classes'],
#  ['best', 'ordered', 'dict', 'implementation', 'python'],
#  ['good', 'two', 'way', 'encryption', 'library', 'implemented', 'python'],
#  ['handle_read', 'method', 'get', 'called', 'asyncore'],
#  ['best',
#   'way',
#   'propagate',
#   'information',
#   'wx',
#   'process',
#   'back',
#   'main',
#   'thread'],
#  ['easiest', 'way', 'get', 'python', 'script', 'output', 'web'],
#  ['difference', 'site', 'app', 'django'],
#  ['send_mail', 'command', 'working', 'django'],
#  ['steps', 'convert', 'using', 'libglade', 'gtkbuilder', 'python'],
#  ['format', 'django', 'passwords', 'stored', 'database'],
#  ['pyd', 'file', 'import', 'computers'],
#  ['purpose', 'sub', 'interpreter', 'api', 'cpython'],
#  ['easiest',
#   'fastest',
#   'way',
#   'measure',
#   'hd',
#   'performance',
#   'using',
#   'python'],
#  ['regex', 'match', 'add', 'groups'],
#  ['csv', 'reader', 'pythonic'],
#  ['pythonic', 'way', 'provide', 'fall', 'back', 'value', 'assignment'],
#  ['best',
#   'secure',
#   'way',
#   'allow',
#   'user',
#   'delete',
#   'model',
#   'instance',
#   'added',
#   'db'],
#  ['python', 'methods', 'passed', 'key', 'argument', 'sorted'],
#  ['shell', 'argument', 'subprocess', 'mean', 'windows'],
#  ['python', 'ellipsis', 'object'],
#  ['arrays', 'numpy', 'considered', 'scalar'],
#  ['generator', 'object', 'django'],
#  ['write', 'log', 'file'],
#  ['wrong', 'attempt', 'string', 'replace', 'operation', 'python'],
#  ['correct', 'way', 'clean', 'using'],
#  ['easiest', 'way', 'build', 'python', 'zip', 'embedded', 'distribution'],
#  ['successful', 'methods', 'deploying', 'django', 'application', 'desktop'],
#  ['best', 'way', 'redirect', 'email', 'python', 'script'],
#  ['builtin', 'functions', 'instead', 'root', 'class', 'methods'],
#  ['json', 'module', 'use', 'python'],
#  ['correct',
#   'best',
#   'way',
#   'subclass',
#   'python',
#   'set',
#   'class',
#   'adding',
#   'new',
#   'instance',
#   'variable'],
#  ['python', 'informixdb', 'package', 'throwing', 'error'],
#  ['best', 'way', 'access', 'stored', 'procedures', 'django', 'orm'],
#  ['phpmailer', 'php', 'class', 'equivalent', 'python'],
#  ['causes', 'genshi', 'template', 'syntax', 'error'],
#  ['version', 'python', 'standardize', 'production', 'development', 'efforts'],
#  ['python',
#   'logging',
#   'package',
#   'support',
#   'printing',
#   'variable',
#   'length',
#   'args'],
#  ['good', 'way', 'mix', 'rss', 'feeds', 'using', 'python'],
#  ['wrong', 'simpy', 'installation'],
#  ['python', 'best', 'ascii', 'unicode', 'database'],
#  ['maya', 'treeview', 'control', 'giving', 'syntax', 'error', 'drag'],
#  ['find', 'hello', 'world', 'simple', 'beautiful', 'soup', 'examples'],
#  ['python', 'feature', 'illustrated', 'code'],
#  ['best',
#   'way',
#   'record',
#   'type',
#   'every',
#   'variable',
#   'assignment',
#   'python',
#   'program'],
#  ['recursive', 'statement', 'wrong'],
#  ['mean', 'python'],
#  ['world', 'python', 'tkinter', 'break', 'using', 'canvas', 'create_image'],
#  ['proper', 'procedure', 'offering', 'patch', 'python', 'documentation'],
#  ['tools',
#   'web',
#   'developers',
#   'use',
#   'php',
#   'ruby',
#   'rails',
#   'python',
#   'etc'],
#  ['best',
#   'way',
#   'programmatically',
#   'log',
#   'web',
#   'site',
#   'order',
#   'screen',
#   'scrape',
#   'preferably',
#   'python'],
#  ['need', 'install', 'python', 'sco'],
#  ['going', 'lambda', 'expression', 'python', 'function'],
#  ['accurate', 'x', 'math', 'sqrt', 'x'],
#  ['good',
#   'ways',
#   'set',
#   'path',
#   'multi',
#   'os',
#   'supported',
#   'python',
#   'script'],
#  ['efficient', 'way', 'find', 'one', 'several', 'substrings', 'python'],
#  ['django', 'giving', 'error', 'module', 'named', 'django', 'core'],
#  ['put', 'method', 'works', 'model'],
#  ['quickest', 'way', 'ruby', 'programmer', 'pick', 'python'],
#  ['efficient',
#   'way',
#   'insert',
#   'thousands',
#   'records',
#   'table',
#   'mysql',
#   'python',
#   'django'],
#  ['open',
#   'source',
#   'python',
#   'java',
#   'library',
#   'provides',
#   'easy',
#   'way',
#   'draw',
#   'circles',
#   'esri',
#   'shapefile'],
#  ['need', 'read', 'microsoft', 'access', 'databases', 'using', 'python'],
#  ['pass', 'direct', 'reference', 'dictionary', 'value', 'function'],
#  ['applications', 'python', 'reload', 'function'],
#  ['whoami', 'python'],
#  ['pep', 'governs', 'ordering', 'dict', 'values'],
#  ['host', 'use', 'making', 'udp', 'socket', 'python'],
#  ['looping', 'range', 'python', 'faster', 'using', 'loop'],
#  ['wrong', 'python', 'code'],
#  ['simplest', 'way', 'extend', 'numpy', 'array', 'dimensions'],
#  ['python', 'equivalent', 'jdbc', 'databasemetadata'],
#  ['return', 'notimplemented', 'instead', 'raising', 'notimplementederror'],
#  ['reason', 'performing', 'double', 'fork', 'creating', 'daemon'],
#  ['exotic', 'function', 'signature', 'python'],
#  ['least',
#   'resource',
#   'intense',
#   'data',
#   'structure',
#   'distribute',
#   'python',
#   'application'],
#  ['wua', 'mode', 'opening', 'file', 'python'],
#  ['pylons', 'close', 'connection', 'subprocess', 'running'],
#  ['python', 'compile', 'source', 'bytecode', 'interpreting'],
#  ['want', 'store', 'none', 'value', 'memcache'],
#  ['idiomatic', 'way', 'invoking', 'list', 'functions', 'python'],
#  ['view', 'google', 'app', 'engine', 'cron', 'admin', 'page'],
#  ['sys', 'exit', 'exit', 'called', 'inside', 'thread', 'python'],
#  ['import', 'allowed'],
#  ['compiler', 'package', 'discontinued', 'python'],
#  ['underlying', 'data', 'structure', 'python', 'lists'],
#  ['use', 'python'],
#  ['process', 'responsible', 'event', 'signalled', 'inotify'],
#  ['calling',
#   'python',
#   'script',
#   'php',
#   'script',
#   'temporary',
#   'file',
#   'created',
#   'console',
#   'run',
#   'created',
#   'via',
#   'php',
#   'invocation'],
#  ['defining', 'class', 'make', 'iterable', 'python'],
#  ['inspect', 'getsource', 'return', 'whole', 'class', 'source'],
#  ['assigning', 'global', 'variables', 'work', 'python'],
#  ['best', 'way', 'fetch', 'render', 'one', 'many', 'relationships'],
#  ['pure', 'python', 'ssh', 'version', 'client', 'implementations'],
#  ['bind', 'tightly', 'negation'],
#  ['anyone', 'care', 'mysqldb', 'bug', 'bug'],
#  ['validating', 'python', 'xml', 'api', 'use'],
#  ['python', 'allow', 'delete', 'files'],
#  ['gps', 'library', 'recommend', 'python'],
#  ['correct', 'way', 'set', 'python', 'locale', 'windows'],
#  ['robot', 'web', 'libraries', 'available', 'python'],
#  ['fastest', 'way', 'draw', 'image', 'gtk'],
#  ['find'],
#  ['proper', 'way', 'compute', 'fully', 'expanded', 'width', 'wx', 'treectrl'],
#  ['percentage', 'sign', 'mean', 'python'],
#  ['official', 'way', 'storing', 'settings', 'python', 'programs'],
#  ['state', 'art', 'pure', 'python', 'xml', 'parser', 'available'],
#  ['clojure', 'equivalent', 'python', 'idiom'],
#  ['logging', 'going', 'infinite', 'loop'],
#  ['line', 'mean', 'python'],
#  ['point', 'os', 'error'],
#  ['gil', 'java', 'virtual', 'machine', 'python', 'need', 'one', 'bad'],
#  ['function', 'python', 'involving', 'urllib', 'beautifulsoup'],
#  ['invalid', 'keys', 'python', 'dicts'],
#  ['reactor', 'use', 'qt'],
#  ['getting',
#   'resultset',
#   'attribute',
#   'findall',
#   'using',
#   'beautifulsoup',
#   'python'],
#  ['equivalent', 'object', 'oriented', 'constructs', 'python'],
#  ['code', 'break', 'loop'],
#  ['bubble', 'sort', 'python', 'slow'],
#  ['mean', 'python'],
#  ['extra', 'blank', 'lines', 'python', 'program', 'output'],
#  ['best',
#   'approach',
#   'creating',
#   'agent',
#   'framework',
#   'python',
#   'flexible',
#   'script',
#   'distribution',
#   'data',
#   'collection'],
#  ['declaring',
#   'descriptor',
#   'class',
#   'function',
#   'break',
#   'descriptor',
#   'functionality'],
#  ['runtime', 'complexity', 'python', 'list', 'functions'],
#  ['easiest', 'way', 'see', 'process', 'given', 'pid', 'exists', 'python'],
#  ['jvm', 'sacrifice', 'order', 'implement', 'tail', 'call', 'optimisation'],
#  ['learn', 'ria'],
#  ['python', 'code', 'hang', 'import', 'compile', 'work', 'shell'],
#  ['purpose', 'two', 'colons', 'python', 'string', 'slicing', 'statement'],
#  ['treedict', 'treemap', 'used', 'practice'],
#  ['typeerror', 'concatenate', 'str', 'list', 'objects', 'mean'],
#  ['self', 'python', 'objects', 'immutable'],
#  ['unexpected', 'indent', 'python'],
#  ['python', 'good', 'functional', 'programming'],
#  ['good', 'data', 'model', 'cross', 'tabulation'],
#  ['whata', 'point', 'inheritance', 'python'],
#  ['write', 'titanium', 'app', 'source', 'code', 'visible', 'users'],
#  ['classes',
#   'applications',
#   'problems',
#   'prefer',
#   'python',
#   'strictly',
#   'oo',
#   'languages'],
#  ['mass',
#   'importing',
#   'work',
#   'importing',
#   'definition',
#   'individually',
#   'works'],
#  ['good', 'beginner', 'setup', 'c', 'python', 'osx'],
#  ['best', 'way', 'implement', 'web', 'service', 'ajax', 'autocomplete'],
#  ['use', 'templating', 'engine', 'python'],
#  ['python', 'equivalent', 'php'],
#  ['difference', 'converting', 'hex', 'client', 'end', 'using', 'rawtohex'],
#  ['reading', 'socket', 'python', 'difference', 'os', 'read', 'socket', 'recv'],
#  ['secure', 'python', 'password', 'encryption'],
#  ['difference', 'python'],
#  ['starting', 'simple_server'],
#  ['write',
#   'python',
#   'script',
#   'run',
#   'devenv',
#   'configure',
#   'debug',
#   'win',
#   'nothing'],
#  ['mean', 'python'],
#  ['call', 'function', 'composition'],
#  ['valid', 'schema', 'rx'],
#  ['easiest', 'way', 'escape', 'html', 'python'],
#  ['best', 'way', 'add', 'api', 'django', 'application'],
#  ['com', 'activex', 'python'],
#  ['list',
#   'comprehension',
#   'using',
#   'zip',
#   'object',
#   'results',
#   'empty',
#   'list'],
#  ['scons', 'variantdir', 'put', 'output', 'given', 'directory'],
#  ['first', 'iterable', 'built', 'function', 'python'],
#  ['correct', 'way', 'use', 'win', 'inet'],
#  ['pythonistas', 'call', 'current', 'reference', 'self'],
#  ['pythonic', 'way', 'write', 'loop'],
#  ['simplest', 'way', 'put', 'python', 'script', 'system', 'tray', 'windows'],
#  ['start', 'openid', 'implementation', 'python', 'api', 'better', 'suits'],
#  ['correct',
#   'way',
#   'pipe',
#   'maven',
#   'output',
#   'python',
#   'screen',
#   'used',
#   'python',
#   'shell',
#   'script'],
#  ['find', 'python', 'crypto', 'package', 'installing', 'paramiko', 'windows'],
#  ['django', 'install', 'ubuntu'],
#  ['next', 'dive', 'python'],
#  ['easiest', 'way', 'handle', 'dates', 'times', 'python'],
#  ['python', 'find', 'shared', 'objects', 'directories', 'sys', 'path'],
#  ['django', 'cache', 'work', 'locmem', 'fail', 'memcached'],
#  ['python', 'test', 'generator', 'simply', 'work'],
#  ['good', 'way', 'render', 'outlined', 'fonts'],
#  ['efficent', 'way', 'store', 'list', 'django', 'models'],
#  ['django',
#   'signal',
#   'handling',
#   'use',
#   'weak',
#   'references',
#   'callbacks',
#   'default'],
#  ['beautifulsoup', 'throwing', 'htmlparseerror'],
#  ['different', 'possible', 'values', 'python', 'script', 'mean'],
#  ['put', 'message', 'queue', 'consumer', 'django'],
#  ['store', 'secret', 'keys', 'password', 'python'],
#  ['ruby', 'python', 'vice', 'versa'],
#  ['point', 'code', 'pattern'],
#  ['simplest', 'possible', 'buildout', 'cfg', 'install', 'zope'],
#  ['better', 'python', 'del', 'delattr'],
#  ['maximum',
#   'simultaneous',
#   'http',
#   'connections',
#   'allowed',
#   'one',
#   'machine',
#   'windows',
#   'server',
#   'using',
#   'python'],
#  ['revision', 'html', 'lib', 'stable'],
#  ['attach', 'pylons', 'request', 'pylons'],
#  ['best', 'practice', 'deploying', 'application', 'windows'],
#  ['exception', 'catches', 'xxxx', 'error', 'python'],
#  ['ipython',
#   'return',
#   'records',
#   'multiple',
#   'fields',
#   'submitting',
#   'query',
#   'sqlite'],
#  ['efficent',
#   'way',
#   'inserting',
#   'thousands',
#   'records',
#   'sqlite',
#   'table',
#   'using',
#   'django'],
#  ['use', 'varargs', 'designing', 'python', 'api'],
#  ['python', 'sys', 'intern', 'used'],
#  ['correct', 'way', 'document', 'kwargs', 'parameter'],
#  ['whata', 'best', 'way', 'get', 'http', 'response', 'code', 'url'],
#  ['quick', 'one', 'liner', 'remove', 'empty', 'lines', 'python', 'string'],
#  ['thread', 'module', 'renamed', 'python', 'x'],
#  ['dry',
#   'way',
#   'configure',
#   'different',
#   'log',
#   'file',
#   'locations',
#   'different',
#   'settings'],
#  ['django', 'model', 'objects', 'attribute', 'defined'],
#  ['man', 'pages', 'module', 'mysqldb', 'python'],
#  ['import', 'zope', 'component', 'python', 'virtualenv'],
#  ['benefit', 'private', 'name', 'mangling', 'python'],
#  ['right', 'way', 'use', 'unicode', 'metadata', 'setup', 'py'],
#  ['python', 'script', 'read', 'last', 'rss', 'post', 'file'],
#  ['basic',
#   'example',
#   'single',
#   'inheritance',
#   'using',
#   'super',
#   'keyword',
#   'python'],
#  ['module',
#   'search',
#   'path',
#   'instead',
#   'typing',
#   'directory',
#   'name',
#   'typing',
#   'file',
#   'name'],
#  ['keyword', 'constraint', 'create', 'table', 'statement'],
#  ['django', 'returning', 'datetime', 'field', 'database'],
#  ['module', 'dict'],
#  ['python', 'tools', 'building', 'database', 'backed', 'webapp'],
#  ['best', 'way', 'call', 'python', 'script', 'another', 'python', 'script'],
#  ['python', 'omits', 'attribute', 'soap', 'message'],
#  ['benefits', 'using', 'cpickle', 'create', 'persistent', 'storage', 'data'],
#  ['trailing', 'slash', 'web', 'service', 'important'],
#  ['python', 'thread', 'unix', 'signals', 'semantics'],
#  ['best', 'way', 'optimize', 'mysql', 'query'],
#  ['good',
#   'way',
#   'replace',
#   'international',
#   'characters',
#   'base',
#   'latin',
#   'counterparts',
#   'using',
#   'python'],
#  ['multiplatform',
#   'alternative',
#   'subprocess',
#   'getstatusoutput',
#   'older',
#   'commands',
#   'python'],
#  ['wrong', 'bit', 'python', 'code', 'using', 'lambda'],
#  ['wxgridsizer', 'much', 'slower', 'initialize', 'wxdialog', 'wxframe'],
#  ['best', 'way', 'putting', 'tabular', 'data', 'python'],
#  ['events', 'bound', 'tkinter', 'frame'],
#  ['json', 'data', 'incoming', 'django', 'request'],
#  ['compatible', 'way', 'install', 'python', 'modules', 'mac'],
#  ['user', 'python', 'scripts', 'run', 'windows'],
#  ['find', 'useful', 'documentation', 'pyusb', 'python', 'usb', 'library'],
#  ['django', 'post_save', 'signal', 'give', 'pre_save', 'data'],
#  ['good',
#   'configuration',
#   'file',
#   'library',
#   'c',
#   'xml',
#   'preferably',
#   'python',
#   'bindings'],
#  ['operator', 'python'],
#  ['simplest', 'way', 'ssh', 'using', 'python'],
#  ['strings', 'python'],
#  ['recommended', 'python', 'module', 'fast', 'fourier', 'transforms', 'fft'],
#  ['python', 'program', 'print', 'true'],
#  ['point', 'gtk'],
#  ['operator', 'perl'],
#  ['importance', 'ide', 'programming', 'python'],
#  ['hidden', 'parameter'],
#  ['path',
#   'module',
#   'class',
#   'python',
#   'folks',
#   'use',
#   'instead',
#   'os',
#   'path'],
#  ['traceback', 'extract_stack', 'return', 'definitely', 'call', 'stack'],
#  ['subprocess',
#   'popen',
#   'shell',
#   'true',
#   'work',
#   'differently',
#   'linux',
#   'vs',
#   'windows'],
#  ['django',
#   'cherrypy',
#   'support',
#   'http',
#   'verb',
#   'based',
#   'dispatch',
#   'natively'],
#  ['python', 'equivalent', 'java', 'inputstream', 'available', 'method'],
#  ['credentials',
#   'put',
#   'google',
#   'app',
#   'engine',
#   'bulkloader',
#   'development',
#   'server'],
#  ['tk', 'examples', 'python', 'distribution', 'written', 'tcl'],
#  ['best', 'way', 'literate', 'programming', 'python', 'windows'],
#  ['import', 'ctypes', 'raise', 'importerror'],
#  ['best', 'way', 'map', 'windows', 'drives', 'using', 'python'],
#  ['correct', 'way', 'generate', 'json', 'file', 'googleappengine'],
#  ['assertraises',
#   'catching',
#   'attribute',
#   'error',
#   'using',
#   'python',
#   'unittest'],
#  ['best', 'way', 'handle', 'rotating', 'sprites', 'top', 'view', 'game'],
#  ['regex', 'removing', 'dots', 'acronyms', 'domain', 'names'],
#  ['orm', 'learn'],
#  ['ruby', 'equivalent', 'python', 'os', 'walk'],
#  ['set', 'global', 'variable', 'python'],
#  ['call',
#   'non',
#   'persistent',
#   'data',
#   'structure',
#   'allows',
#   'persistent',
#   'operations'],
#  ['get', 'technical', 'information', 'internals', 'django', 'works'],
#  ['python', 'method', 'gives', 'error', 'saying', 'global', 'name', 'defined'],
#  ['development',
#   'environment',
#   'use',
#   'developing',
#   'google',
#   'app',
#   'engine',
#   'python'],
#  ['catch',
#   'exception',
#   'get',
#   'type',
#   'file',
#   'line',
#   'number',
#   'previous',
#   'frame'],
#  ['global', 'interpreter', 'lock', 'gil'],
#  ['difference', 'import', 'vs', 'import'],
#  ['regex', 'use', 'capture', 'groups', 'string'],
#  ['standard',
#   'input',
#   'displayed',
#   'type',
#   'mac',
#   'os',
#   'x',
#   'terminal',
#   'application'],
#  ['simplest',
#   'way',
#   'python',
#   'print',
#   'remote',
#   'ipp',
#   'cups',
#   'server',
#   'printer'],
#  ['possible', 'values', 'datetime', 'strptime', 'accept', 'z'],
#  ['built', 'method', 'decode', 'mean', 'python', 'profiling'],
#  ['best',
#   'way',
#   'create',
#   'python',
#   'object',
#   'class',
#   'implementaion',
#   'stored',
#   'string'],
#  ['oldest', 'time', 'represented', 'python'],
#  ['best',
#   'place',
#   'put',
#   'cache',
#   'evicting',
#   'logic',
#   'appengine',
#   'application'],
#  ['construct', 'called', 'python', 'x'],
#  ['make', 'python', 'error'],
#  ['necessary', 'add', 'else', 'clause', 'try', 'except', 'python'],
#  ['efficient', 'string', 'concatenation', 'method', 'python'],
#  ['borg', 'pattern', 'better', 'singleton', 'pattern', 'python'],
#  ['efficient', 'way', 'add', 'element', 'list', 'yet'],
#  ['required', 'functionnalities', 'etl', 'frameworks'],
#  ['numbers',
#   'pass',
#   'verbosity',
#   'running',
#   'python',
#   'unit',
#   'test',
#   'suites'],
#  ['best', 'way', 'use', 'python', 'functions', 'excel'],
#  ['get',
#   'service',
#   'unavailable',
#   'multiple',
#   'chat',
#   'sends',
#   'using',
#   'xmpp'],
#  ['fastest', 'template', 'system', 'python'],
#  ['python',
#   'modules',
#   'available',
#   'assist',
#   'daemonization',
#   'standard',
#   'library'],
#  ['order', 'sqlalchemy', 'use', 'primary', 'key', 'columns'],
#  ['cross',
#   'browser',
#   'support',
#   'javascript',
#   'new',
#   'features',
#   'specifically',
#   'array',
#   'comprehensions',
#   'statement'],
#  ['weakproxy', 'always', 'preserve', 'equivalence', 'python'],
#  ['fastest', 'way', 'fixup', 'line', 'endings', 'smtp', 'sending'],
#  ['wrong', 'simplexmlrpc', 'dbusgmainloop', 'working', 'time'],
#  ['saving', 'msword', 'document', 'silently', 'fail'],
#  ['pythonic', 'way', 'determining', 'endianness'],
#  ['matrix', 'mean', 'python', 'numpy'],
#  ['core', 'conceptual', 'differences', 'c', 'python'],
#  ['python', 'enumerate', 'slow'],
#  ['activepython', 'exist'],
#  ['usr',
#   'bin',
#   'env',
#   'python',
#   'supposedly',
#   'correct',
#   'usr',
#   'bin',
#   'python'],
#  ['namespace', 'method', 'call', 'changes'],
#  ['server',
#   'equivalent',
#   'django',
#   'test',
#   'client',
#   'test',
#   'external',
#   'url',
#   'fetch'],
#  ['cause',
#   'zip',
#   'file',
#   'recognized',
#   'google',
#   'app',
#   'engine',
#   'reads',
#   'properly',
#   'local',
#   'gae',
#   'sdk'],
#  ['exploded', 'python', 'code', 'actually', 'running', 'faster'],
#  ['piece', 'python', 'code'],
#  ['faster', 'python', 'xrange'],
#  ['kind',
#   'setup',
#   'ide',
#   'et',
#   'al',
#   'need',
#   'run',
#   'ironpython',
#   'unit',
#   'tests',
#   'c',
#   'net',
#   'developed',
#   'assemblies'],
#  ['lightweight', 'python', 'library', 'simple', 'scientific', 'visualization'],
#  ['pep', 'must', 'reads'],
#  ['one',
#   'place',
#   'code',
#   'autoincrement',
#   'sharded',
#   'counter',
#   'google',
#   'app',
#   'engine',
#   'django',
#   'one',
#   'creates',
#   'new',
#   'model'],
#  ['wrong', 'simple', 'http', 'proxy', 'script', 'python', 'socket', 'based'],
#  ['different',
#   'options',
#   'processing',
#   'uploaded',
#   'pdf',
#   'files',
#   'django',
#   'application'],
#  ['python', 'data', 'structure', 'parser', 'use', 'apple', 'system_profiler'],
#  ['subtraction', 'faster', 'addition', 'python'],
#  ['simplest',
#   'way',
#   'implement',
#   'remote',
#   'fifo',
#   'queue',
#   'python',
#   'gae',
#   'application'],
#  ['list', 'clear', 'method', 'python'],
#  ['upload', 'jpg', 'files', 'django', 'app', 'via', 'admin'],
#  ['simplest',
#   'url',
#   'shortener',
#   'application',
#   'one',
#   'write',
#   'python',
#   'google',
#   'app',
#   'engine'],
#  ['enable', 'shared', 'failed', 'happen', 'libjpeg', 'build', 'os', 'x'],
#  ['typeerror', 'using', 'tkinter'],
#  ['class', 'use', 'money', 'representation'],
#  ['facebook', 'new', 'tornado', 'framework'],
#  ['python', 'gettext', 'module', 'require', 'compilation', 'step', 'po', 'mo'],
#  ['pros', 'cons', 'pyro', 'rpyc', 'python', 'libs'],
#  ['difference', 'makes', 'set', 'python', 'thread', 'deamon'],
#  ['use',
#   'kwargs',
#   'python',
#   'real',
#   'world',
#   'advantages',
#   'using',
#   'named',
#   'arguments'],
#  ['pythonic', 'array', 'removal'],
#  ['python', 'documentation', 'special', 'methods'],
#  ['variable', 'name', 'use', 'file', 'descriptors'],
#  ['python', 'mpi', 'library', 'use'],
#  ['python',
#   'web',
#   'frameworks',
#   'work',
#   'well',
#   'cgi',
#   'nearlyfreespeech',
#   'net'],
#  ['best', 'design', 'polling', 'modem', 'incoming', 'data'],
#  ['wrong', 'python', 'function', 'programming', 'collective', 'intelligence'],
#  ['ways', 'run', 'server', 'side', 'script', 'forever'],
#  ['keycode', 'control', 'z', 'key', 'python'],
#  ['risks', 'mixing', 'psyco', 'project'],
#  ['psyco', 'use', 'lot', 'memory'],
#  ['builtin', 'name', 'type', 'functions', 'python'],
#  ['get', 'error', 'keyerror', 'wsgi', 'input'],
#  ['error', 'python', 'code'],
#  ['best', 'maintained', 'generic', 'functions', 'implementation', 'python'],
#  ['python', 'class', 'definition', 'assign', 'closure', 'variable'],
#  ['proper',
#   'idiom',
#   'naming',
#   'django',
#   'model',
#   'fields',
#   'python',
#   'reserved',
#   'names'],
#  ['good', 'names', 'user', 'defined', 'exceptions'],
#  ['best', 'benefits', 'using', 'pinax'],
#  ['queue', 'appropriate'],
#  ['python', 'dict', 'update', 'return', 'object'],
#  ['django',
#   'python',
#   'solution',
#   'providing',
#   'one',
#   'time',
#   'url',
#   'people',
#   'download',
#   'files'],
#  ['pysqlite', 'work', 'properly'],
#  ['python', 'keep', 'reference', 'count', 'false', 'true'],
#  ['sqlite', 'development', 'headers', 'install'],
#  ['accepted',
#   'python',
#   'alternative',
#   'c',
#   'overloaded',
#   'input',
#   'stream',
#   'operators'],
#  ['pythonic', 'way', 'checking', 'object', 'list'],
#  ['involved', 'adding', 'standard', 'python', 'api'],
#  ['language', 'use', 'fast', 'execution', 'database', 'summarization', 'task'],
#  ['networking', 'libraries', 'frameworks', 'exist', 'python'],
#  ['import', 'math', 'library', 'embedding', 'python', 'c'],
#  ['receiving',
#   'low',
#   'level',
#   'socket',
#   'error',
#   'using',
#   'fabric',
#   'python',
#   'library'],
#  ['windowserror', 'deleting', 'temporary', 'file'],
#  ['going', 'code', 'google', 'app', 'engine', 'tutorial'],
#  ['setup', 'py'],
#  ['python', 'equivalent', 'application', 'session', 'scope', 'variables'],
#  ['host', 'aborting', 'connection'],
#  ['happens', 'python', 'object', 'throw', 'exception'],
#  ['life', 'time', 'thread', 'local', 'value', 'python'],
#  ['python', 'see', 'pysqlite'],
#  ['python', 'fabric', 'equivalent', 'languages'],
#  ['method', 'call'],
#  ['difference', 'sqlite', 'pysqlite', 'sqlite', 'modules'],
#  ['get', 'urllib', 'httperror', 'urllib', 'errors', 'urllib'],
#  ['mean', 'weakly', 'referenced', 'object', 'longer', 'exists'],
#  ['build', 'chain', 'methods', 'method', 'method', 'method'],
#  ['good', 'way', 'combinate', 'set'],
#  ['mysqldb', 'mac', 'mysql', 'installed', 'install'],
#  ['crop', 'image', 'python', 'pil', 'simple', 'syntax', 'problem'],
#  ['good', 'python', 'libraries', 'following', 'needs'],
#  ['advisable', 'use', 'ret_val', 'variable'],
#  ['right',
#   'way',
#   'override',
#   'copy',
#   'deepcopy',
#   'operations',
#   'object',
#   'python'],
#  ['pythonic', 'way', 'ensure', 'elements', 'list', 'different'],
#  ['comparing',
#   'strings',
#   'python',
#   'using',
#   'either',
#   'sometimes',
#   'produce',
#   'different',
#   'result'],
#  ['os', 'system', 'set', 'foo', 'bar', 'work'],
#  ['advantages', 'faster', 'server', 'side', 'scripting', 'languages'],
#  ['thumbnail', 'pil', 'function', 'work', 'nd', 'time'],
#  ['good', 'reference', 'server', 'side', 'development'],
#  ['use', 'instead', 'assignment', 'expression', 'python'],
#  ['code', 'getting', 'nzec', 'run', 'time', 'error'],
#  ['good',
#   'library',
#   'computational',
#   'geometry',
#   'like',
#   'cgal',
#   'garbage',
#   'collected',
#   'language'],
#  ['best', 'way', 'read', 'python', 'documentation', 'installed', 'packages'],
#  ['good', 'size', 'bytes', 'log', 'file'],
#  ['common', 'header', 'format', 'python', 'files'],
#  ['get',
#   'encoding',
#   'error',
#   'python',
#   'warnings',
#   'formatwarning',
#   'format',
#   'string'],
#  ['save', 'object', 'django'],
#  ['urllib', 'missing', 'table', 'fields', 'see', 'firefox', 'source'],
#  ['useful', 'non', 'built', 'django', 'tags'],
#  ['function', 'hangs'],
#  ['need', 'know', 'learn', 'automated', 'python', 'deployment'],
#  ['python', 'strings', 'tuples', 'made', 'immutable'],
#  ['getopt', 'working', 'sys', 'argv', 'passed', 'fully'],
#  ['subprocess', 'popen', 'waiting', 'child', 'process', 'terminates'],
#  ['list', 'argument', 'python', 'behave', 'like', 'byref'],
#  ['django', 'query', 'returns', 'none', 'gives', 'error'],
#  ['ldap', 'object', 'mapper', 'python', 'recommend'],
#  ['needed', 'add', 'like', 'effect', 'photos', 'python'],
#  ['happen', 'template', 'django'],
#  ['memcache', 'work', 'django'],
#  ['use', 'builtin', 'function', 'property', 'python'],
#  ['pythonic',
#   'installing',
#   'python',
#   'modules',
#   'via',
#   'package',
#   'manager',
#   'macports',
#   'apt',
#   'via',
#   'pip',
#   'easy_install',
#   'setuptools'],
#  ['good', 'example', 'method', 'collection', 'class'],
#  ['possibilities',
#   'exist',
#   'build',
#   'installer',
#   'windows',
#   'application',
#   'linux',
#   'install',
#   'target',
#   'windows',
#   'build',
#   'environment',
#   'linux'],
#  ['pure', 'python', 'library', 'use', 'scrape', 'website'],
#  ['app', 'django'],
#  ['find', 'documentation', 'python', 'library', 'inner', 'workings'],
#  ['python', 'append', 'push'],
#  ['beautifulsoup', 'modifying', 'self', 'closing', 'elements'],
#  ['typical', 'workflow', 'development', 'zenoss', 'zenpack'],
#  ['else',
#   'behave',
#   'differently',
#   'statements',
#   'opposed',
#   'try',
#   'statements'],
#  ['function'],
#  ['check', 'state', 'throw', 'exception'],
#  ['best',
#   'way',
#   'search',
#   'python',
#   'dictionary',
#   'value',
#   'list',
#   'dictionaries'],
#  ['lambda', 'mean', 'python', 'simplest', 'way', 'use'],
#  ['correct', 'way', 'process', 'bits', 'inside', 'octet', 'python'],
#  ['use', 'cases', 'non', 'relational', 'datastores'],
#  ['show', 'processlist', 'qtsql', 'pyqt'],
#  ['simple',
#   'math',
#   'operations',
#   'floating',
#   'point',
#   'return',
#   'unexpected',
#   'inaccurate',
#   'results',
#   'vb',
#   'net',
#   'python'],
#  ['python', 'client', 'library', 'use', 'couchdb'],
#  ['c', 'c', 'lisp', 'prevalent', 'embedded', 'devices', 'robots'],
#  ['import', 'python', 'module', 'signal', 'using', 'jython', 'linux'],
#  ['simple', 'python', 'class', 'working'],
#  ['right', 'way', 'design', 'adventure', 'game', 'pygame'],
#  ['files', 'need', 'include', 'python', 'app'],
#  ['best',
#   'way',
#   'store',
#   'integers',
#   'mapped',
#   'strings',
#   'keys',
#   'ranges',
#   'python'],
#  ['profiling',
#   'tools',
#   'exist',
#   'python',
#   'linux',
#   'beyond',
#   'ones',
#   'included',
#   'standard',
#   'library'],
#  ['new', 'python', 'x'],
#  ['use', 'alternative', 'python', 'distribution'],
#  ['causing',
#   'unbound',
#   'method',
#   'must',
#   'called',
#   'instance',
#   'first',
#   'argument',
#   'python',
#   'code'],
#  ['key', 'value', 'store', 'use', 'python'],
#  ['wrong', 'setup', 'py'],
#  ['causing', 'python', 'exception'],
#  ['white', 'listing', 'certain', 'html', 'tags', 'python'],
#  ['exactly', 'register', 'machine'],
#  ['pythonic', 'way', 'detect', 'last', 'element', 'python', 'loop'],
#  ['simplest',
#   'cross',
#   'platform',
#   'way',
#   'pop',
#   'graphical',
#   'dialogs',
#   'python'],
#  ['wrong', 'django', 'model', 'field'],
#  ['many', 'google', 'app', 'engine', 'django'],
#  ['python', 'find', 'path', 'django'],
#  ['getting', 'error', 'django'],
#  ['many',
#   'apps',
#   'frameworks',
#   'keep',
#   'configuration',
#   'files',
#   'un',
#   'executed',
#   'format'],
#  ['get', 'error', 'try', 'print', 'something', 'putty'],
#  ['whether', 'use', 'set', 'names'],
#  ['default', 'arguments', 'evaluated', 'definition', 'time', 'python'],
#  ['need', 'explicitly', 'delete', 'sys', 'exc_info', 'traceback', 'python'],
#  ['python',
#   'favourite',
#   'among',
#   'people',
#   'working',
#   'animation',
#   'industry'],
#  ['difference', 'basehttpserver', 'simplehttpserver', 'use'],
#  ['python', 'daemon', 'hog', 'cpu', 'sleeping'],
#  ['python', 'mmap', 'work', 'large', 'files'],
#  ['may', 'problem', 'django', 'views'],
#  ['install', 'order', 'able', 'use', 'gtk', 'python', 'ubuntu'],
#  ['evaluated', 'mean', 'chained', 'comparisons', 'python'],
#  ['issubclass', 'equivalent', 'isinstance', 'python'],
#  ['setuptools', 'installed'],
#  ['python', 'first', 'look', 'files'],
#  ['difference', 'static', 'method', 'class', 'method', 'python'],
#  ['python', 'v', 'write', 'error', 'stream'],
#  ['backticks', 'mean', 'python', 'interpreter', 'num'],
#  ['python', 'list', 'append', 'evaluate', 'false'],
#  ['cycles', 'relation', 'python'],
#  ['maths', 'operator', 'python'],
#  ['easiest',
#   'way',
#   'finding',
#   'child',
#   'instance',
#   'parent',
#   'instance',
#   'django'],
#  ['perfer', 'store', 'serialized', 'data', 'raw', 'code', 'db'],
#  ['pylons', 'use', 'instead', 'threading', 'local'],
#  ['str', 'lstrip', 'strips', 'extra', 'character'],
#  ['default', 'chunker', 'nltk', 'toolkit', 'python'],
#  ['assignment', 'double', 'sliced', 'numpy', 'arrays', 'work'],
#  ['getting', 'little', 'endian', 'error', 'importing', 'file', 'python'],
#  ['cause', 'select', 'block', 'python'],
#  ['technologies',
#   'good',
#   'sending',
#   'encapsulated',
#   'data',
#   'later',
#   'converting',
#   'python',
#   'objective',
#   'c'],
#  ['scripting', 'engine'],
#  ['cool', 'hacks', 'done', 'using', 'sys', 'settrace'],
#  ['use', 'python', 'basic', 'optimizations', 'mode', 'python'],
#  ['return', 'value', 'subprocess', 'call'],
#  ['database', 'use', 'store', 'records', 'use'],
#  ['tools',
#   'used',
#   'produce',
#   'beautiful',
#   'documentation',
#   'python',
#   'project'],
#  ['meant', 'array', 'support'],
#  ['brackets', 'mean', 'python', 'table', 'r', 'pos'],
#  ['suggested', 'seed', 'value', 'use', 'random', 'seed'],
#  ['dht', 'implementations', 'compatible', 'python', 'x'],
#  ['u', 'mean', 'list'],
#  ['jabber',
#   'xmpp',
#   'libraries',
#   'available',
#   'pys',
#   'python',
#   'symbian',
#   'interpreter'],
#  ['one',
#   'programs',
#   'runs',
#   'python',
#   'imports',
#   'something',
#   'requires',
#   'python'],
#  ['python',
#   'x',
#   'dht',
#   'implementation',
#   'going',
#   'easiest',
#   'port',
#   'python',
#   'x'],
#  ['square', 'brackets', 'mean', 'function', 'class', 'documentation'],
#  ['yahoo', 'openid', 'discovery', 'endpoint'],
#  ['python', 'code', 'shell', 'sys', 'platform', 'win'],
#  ['equivalent', 'matlab', 'repmat', 'numpy'],
#  ['cas', 'implementation', 'use', 'django'],
#  ['find', 'python', 'lib', 'documentation'],
#  ['suitable', 'buffer', 'python', 'struct', 'module'],
#  ['efficient',
#   'python',
#   'new',
#   'array',
#   'creation',
#   'place',
#   'array',
#   'manipulation'],
#  ['psycopg',
#   'executing',
#   'sql',
#   'functions',
#   'indexerror',
#   'tuple',
#   'index',
#   'range'],
#  ['wrong', 'program'],
#  ['good',
#   'option',
#   'non',
#   'blocking',
#   'database',
#   'using',
#   'tcp',
#   'socket',
#   'server'],
#  ['max', 'length', 'python', 'string'],
#  ['python',
#   'program',
#   'average',
#   'cpu',
#   'per',
#   'process',
#   'make',
#   'python',
#   'use',
#   'available',
#   'cpu'],
#  ['pythonic',
#   'xhtml',
#   'html',
#   'parser',
#   'generator',
#   'template',
#   'module',
#   'supports',
#   'dom',
#   'like',
#   'access'],
#  ['python', 'scatter', 'plot', 'work'],
#  ['pythonic', 'way', 'normalizing', 'lineends', 'string'],
#  ['conditions', 'cause', 'tokyo', 'cabinet', 'block'],
#  ['approach',
#   'es',
#   'used',
#   'lightweight',
#   'python',
#   'unit',
#   'tests',
#   'app',
#   'engine'],
#  ['causing',
#   'importerror',
#   'module',
#   'named',
#   'pkg_resources',
#   'upgrade',
#   'python',
#   'os',
#   'x'],
#  ['right', 'way', 'organize', 'python', 'unittests', 'suites'],
#  ['best', 'python', 'zip', 'module', 'handle', 'large', 'files'],
#  ['print', 'something', 'always', 'unicode', 'next', 'python'],
#  ['differences', 'variable', 'scoping', 'python', 'scheme'],
#  ['getting', 'error', 'python', 'httplib'],
#  ['best', 'way', 'crawl', 'login', 'based', 'sites'],
#  ['best',
#   'framework',
#   'cms',
#   'shopping',
#   'cart',
#   'plugin',
#   'module',
#   'etc',
#   'combination'],
#  ['best', 'browser', 'automation', 'tool', 'python'],
#  ['python', 'features', 'excite', 'interest', 'c', 'developer'],
#  ['programming',
#   'language',
#   'short',
#   'context',
#   'free',
#   'grammar',
#   'formal',
#   'specification'],
#  ['get', 'error', 'python', 'code'],
#  ['find',
#   'current',
#   'example',
#   'code',
#   'bulk',
#   'upload',
#   'data',
#   'google',
#   'appengine',
#   'localhost'],
#  ['wrong', 'pearson', 'algorithm', 'programming', 'collective'],
#  ['python', 'allow', 'comparison', 'callable', 'number'],
#  ['drop', 'support', 'python', 'public', 'python', 'library'],
#  ['abstract', 'mean', 'context'],
#  ['two', 'math', 'functions', 'return', 'result'],
#  ['virtualenv', 'code', 'go'],
#  ['efficent', 'way', 'implement', 'concurrency', 'python'],
#  ['use', 'uuid', 'uuid', 'vs', 'uuid', 'uuid', 'python'],
#  ['python', 'pydoc', 'help', 'function', 'get', 'content'],
#  ['true', 'difference', 'lemmatization', 'vs', 'stemming'],
#  ['limits', 'python'],
#  ['fool',
#   'proof',
#   'way',
#   'convert',
#   'string',
#   'utf',
#   'else',
#   'simple',
#   'ascii',
#   'string',
#   'python'],
#  ['send', 'post', 'request', 'python'],
#  ['swig', 'crash', 'python', 'linked', 'gtkglext'],
#  ['mechanism', 'use', 'integrate', 'python', 'languages', 'net', 'java'],
#  ['paste', 'script'],
#  ['python', 'ruby', 'interpreted'],
#  ['performance',
#   'cost',
#   'named',
#   'keys',
#   'pre',
#   'generated',
#   'keys',
#   'google',
#   'app',
#   'engine'],
#  ['validation', 'transformations', 'entities', 'google', 'app', 'engine'],
#  ['need', 'save', 'model', 'adding', 'another', 'one'],
#  ['default', 'content', 'type', 'charset'],
#  ['say', 'x', 'x', 'python'],
#  ['find', 'good', 'tutorials', 'guides', 'wxpython', 'wxglade'],
#  ['python', 'script', 'randomly', 'get', 'killed'],
#  ['use', 'remote', 'desktop', 'control'],
#  ['use', 'wsgi'],
#  ['wrong', 'digit', 'finder', 'python'],
#  ['join', 'tuple', 'python'],
#  ['sort', 'list'],
#  ['preferred',
#   'technique',
#   'convert',
#   'object',
#   'properties',
#   'sorted',
#   'list',
#   'tuples'],
#  ['easy', 'way', 'implement', 'quiet', 'option', 'python', 'script'],
#  ['pip',
#   'install',
#   'python',
#   'couchdb',
#   'experimental',
#   'branch',
#   'svn',
#   'fail'],
#  ['csvwriter', 'writerow', 'put', 'comma', 'character'],
#  ['functional', 'tools', 'remain', 'python', 'k'],
#  ['errors', 'handle'],
#  ['best', 'way', 'divide', 'large', 'files', 'python', 'multiprocessing'],
#  ['better',
#   'language',
#   'c',
#   'python',
#   'complex',
#   'problem',
#   'solving',
#   'exercises',
#   'ex',
#   'graphs'],
#  ['see', 'import', 'name', 'error', 'using', 'google', 'protocol', 'buffers'],
#  ['ghost', 'process', 'appears', 'kill'],
#  ['co', 'compiled', 'one', 'mac', 'work', 'another'],
#  ['python', 'builtin'],
#  ['python', 'http', 'web', 'servers', 'available'],
#  ['range', 'values', 'float', 'python'],
#  ['internal', 'representation', 'string', 'python', 'x'],
#  ['functions', 'always', 'return', 'type'],
#  ['dir', 'named', 'dir', 'python'],
#  ['modules', 'consider', 'python', 'wish', 'use', 'cgi', 'sessions'],
#  ['difference', 'crypto', 'use'],
#  ['advantages',
#   'disadvantages',
#   'require',
#   'vs',
#   'import',
#   'methods',
#   'loading',
#   'code'],
#  ['best',
#   'python',
#   'idiom',
#   'grouping',
#   'list',
#   'items',
#   'groups',
#   'specific',
#   'max',
#   'size'],
#  ['pros', 'cons', 'various', 'twitter', 'api', 'libraries', 'python'],
#  ['pdb', 'displaying', 'blank', 'comment', 'try', 'set', 'break'],
#  ['options', 'mysql', 'python'],
#  ['best', 'way', 'call', 'java', 'code', 'python'],
#  ['jython', 'useful'],
#  ['invalid', 'syntax'],
#  ['good',
#   'general',
#   'way',
#   'look',
#   'sqlalchemy',
#   'transactions',
#   'complete',
#   'authenticated',
#   'user',
#   'etc'],
#  ['first', 'argument', 'type'],
#  ['languages', 'python', 'explicit', 'self'],
#  ['python', 'language', 'rule', 'allows', 'descriptor', 'found', 'first'],
#  ['python', 'interpreter', 'none'],
#  ['python', 'class', 'claim', 'arguments', 'instead'],
#  ['script', 'work', 'manualy', 'insert', 'mysql'],
#  ['python',
#   'calculated',
#   'hashlib',
#   'sha',
#   'different',
#   'git',
#   'hash',
#   'object',
#   'file'],
#  ['loop', 'example'],
#  ['python', 'reusing', 'class', 'instance', 'inside', 'function'],
#  ['signal', 'connected', 'initial', 'dialog', 'display', 'pyqt', 'qt'],
#  ['best', 'way', 'get', 'stacktrace', 'using', 'multiprocessing'],
#  ['django', 'manager', 'code', 'live'],
#  ['property', 'validations', 'run', 'google', 'app', 'engine', 'gae'],
#  ['put', 'django', 'template', 'dependent', 'files'],
#  ['result', 'status_code', 'python', 'mean'],
#  ['various',
#   'popularity',
#   'metrics',
#   'sites',
#   'programming',
#   'languages',
#   'ruby',
#   'python',
#   'java',
#   'etc'],
#  ['program', 'functionally', 'python'],
#  ['import', 'urlfetch', 'google', 'app', 'engines'],
#  ['getting', 'file', 'permission', 'error', 'python'],
#  ['django', 'say', 'set', 'database_engine', 'yet'],
#  ['difference', 'methods', 'python'],
#  ['sqlalchemy', 'associationproxy', 'duplicating', 'tags'],
#  ['neater', 'pythonic', 'way', 'following', 'enumeration'],
#  ['standard', 'sort', 'order', 'python', 'release', 'version', 'numbers'],
#  ['list', 'comprehension', 'called', 'python'],
#  ['correct', 'method', 'handling', 'events', 'pyqt'],
#  ['whether', 'simplify', 'two', 'stage', 'regular', 'expression'],
#  ['python', 'used'],
#  ['best', 'way', 'store', 'database', 'settings', 'django'],
#  ['real', 'lightweight', 'threads', 'python'],
#  ['python', 'gil', 'garbage', 'collector'],
#  ['using',
#   'py',
#   'app',
#   'way',
#   'customize',
#   'traceback',
#   'dialog',
#   'gets',
#   'displayed',
#   'show',
#   'different',
#   'cocoa',
#   'dialog'],
#  ['hashtable', 'dictionary', 'implementation', 'python', 'store', 'keys'],
#  ['better', 'way', 'handle', 'python'],
#  ['bad', 'threadlocals'],
#  ['problems', 'one', 'see', 'using', 'python', 'multiprocessing', 'naively'],
#  ['blocking', 'non', 'blocking', 'web', 'server', 'difference'],
#  ['use',
#   'strings',
#   'like',
#   'mode',
#   'python',
#   'found',
#   'top',
#   'python',
#   'files'],
#  ['exec', 'eval', 'avoided'],
#  ['use', 'django', 'google', 'app', 'engine'],
#  ['code', 'behave', 'differently', 'python', 'python'],
#  ['django',
#   'throw',
#   'exception',
#   'whenever',
#   'enable',
#   'admin',
#   'autodiscover'],
#  ['ctypes', 'writeprocessmemory', 'fail'],
#  ['difference', 'b', 'place'],
#  ['count', 'working', 'way', 'expect', 'code'],
#  ['relationship', 'getattr'],
#  ['following', 'code', 'always', 'output'],
#  ['os', 'path', 'join', 'work', 'case'],
#  ['classmethod', 'code'],
#  ['purpose', 'deepcopy', 'second', 'parameter', 'memo'],
#  ['call'],
#  ['python', 'syntax', 'error', 'initialisation'],
#  ['eval', 'function', 'work', 'think', 'print', 'b'],
#  ['python', 'super', 'accept', 'instance'],
#  ['twisted',
#   'wokkel',
#   'xmpp',
#   'examples',
#   'ignore',
#   'proper',
#   'usage',
#   'jid',
#   'xmpp',
#   'protocol'],
#  ['dict', 'objects', 'unhashable', 'python'],
#  ['extjs', 'combobox', 'filled', 'dynamically'],
#  ['dummy', 'modules', 'sys', 'modules'],
#  ['join', 'function', 'run', 'wrong'],
#  ['execution', 'resume', 'following', 'exception'],
#  ['exactly', 'random', 'random'],
#  ['django', 'code'],
#  ['code', 'print', 'bbb', 'run', 'wrong', 'unexpectedly'],
#  ['significance', 'function', 'without', 'self', 'argument', 'insde', 'class'],
#  ['exception', 'raise', 'wrong', 'number', 'arguments', 'passed', 'args'],
#  ['formfield', 'method', 'called', 'django'],
#  ['next', 'code', 'mean', 'lambda', 'request', 'kwargs', 'never', 'see'],
#  ['call', 'function'],
#  ['getattr', 'working', 'like', 'think', 'think', 'code', 'print', 'sss'],
#  ['code', 'run', 'wrong', 'property'],
#  ['call', 'packagename', 'modulename', 'foo'],
#  ['def', 'syntax', 'error'],
#  ['function', 'local', 'python', 'variables', 'created'],
#  ['code', 'print', 'os', 'path'],
#  ['best', 'way', 'profile', 'view', 'django'],
#  ['arguments', 'python', 'sort', 'function'],
#  ['happen', 'python', 'list', 'sort'],
#  ['use', 'map', 'instead', 'loop'],
#  ['django', 'site', 'return', 'checked', 'url', 'parser'],
#  ['code'],
#  ['causes',
#   'subprocess',
#   'call',
#   'output',
#   'blank',
#   'file',
#   'attempting',
#   'db',
#   'export',
#   'mysqldump'],
#  ['difference', 'isinstance', 'aaa', 'basestring', 'isinstance', 'aaa', 'str'],
#  ['python', 'print', 'function', 'actually'],
#  ['makes', 'pylint', 'think', 'class', 'abstract'],
#  ['best',
#   'way',
#   'set',
#   'symbolic',
#   'links',
#   'current',
#   'installs',
#   'python',
#   'python'],
#  ['tell', 'call', 'built', 'functions', 'next', 'code'],
#  ['unexpected', 'indent'],
#  ['code', 'make', 'dead', 'loop', 'iter', 'c'],
#  ['code', 'next', 'function', 'called', 'example'],
#  ['fundamental', 'python', 'functions', 'python', 'object', 'methods'],
#  ['place', 'one', 'time', 'operation', 'operation', 'django', 'framework'],
#  ['python', 'sign', 'function'],
#  ...]

# %%
#Sentence Embedding
import numpy as np
def sentence_emb(question,word_vect,dim = 200):
    question_embedding = np.zeros(dim)
    valid_words = 0
    for word in question:
        if word in word_vect.vocab:
            valid_words += 1
            question_embedding += word_vect[word]
    if valid_words > 0:
        return question_embedding/valid_words
    else:
        return question_embedding
all_title_embeddings = []
i = 0
for question in word2vec_list:
    if question != []:
        list_val = list(sentence_emb(question, word_vect))
        all_title_embeddings.append(list_val)

# %%
#Identifying empty values - to merge the processed data we have to get their index value. 
i = 0
empty_values = []
for question in word2vec_list:
    if question == []:
        empty_values.append(i)
    else:
        i = i+1

# %%
#Removing empty values from data - empty values corresponds to titles with no proper details
Wh_df_1 = Wh_df.copy(deep = True)
Wh_df_1 = Wh_df_1.drop(Wh_df_1.index[empty_values])
ids_fil = Wh_df_1.index

# %% [markdown]
# #### Feature Extraction - Bert Embedding

# %%
from sentence_transformers import SentenceTransformer
embedder = SentenceTransformer('bert-base-nli-mean-tokens')

# %%
#Converting text to vectors 
question_embeddings = embedder.encode(Question_data_filtered)

# %% [markdown]
# **Search Question Processing**
#
# **Text Similarity - Probe Question & Question Corpus**

# %%
query = ["How to find version of python installed in my system"]
#Bert Encoding
query_embedding = list(embedder.encode(query))
ids = Wh_df.index
#Creating dataframe that holds all processed titles with index 
df_bert = pd.DataFrame({'pos':ids, 'en_ques':Question_data_filtered})
#cosine similarity
df_res = pd.DataFrame()
import scipy.spatial
distances = scipy.spatial.distance.cdist([list(query_embedding[0])], question_embeddings, "cosine")[0]
results = zip(range(len(distances)), distances)
results = sorted(results, key=lambda x: x[1])
#Fetching top 5 similar question
for idx, distance in results[0:5]:
    index_val = list(df_bert[df_bert['en_ques'] == Question_data_filtered[idx]]['pos'])
    df_v = pd.DataFrame({'Id': Wh_df[Wh_df.index.isin(index_val)]['Id'],'Title':Wh_df[Wh_df.index.isin(index_val)]['Title'],
                         'Score': 1-distance })
    df_res = df_res.append(df_v)
    #print(Question_data_filtered[idx].strip(), "(Score: %.4f)" % (1-distance))
df_res
# Out:
#               Id                                              Title     Score
# 83866    8917885       Which version of Python do I have installed?  0.943389
# 375196  29458249  Which version of Pip to use with my Python ins...  0.931776
# 417133  31678261  Where is a program that will let me execute Py...  0.925464
# 24906    3049569  Where do I put utility functions in my Python ...  0.921216
# 180429  17098004  which version of python is used when I run it ...  0.919910

# %%
#Word2vec Encoding
#Search Question Preprocessing
Question_data_query = list(simple_process(query))
Question_data_filtered1_query = [rem_stop(question) for question in Question_data_query ]
word2vec_list_query = [unseen_words(question) for question in Question_data_filtered1_query ]
query_emb = list(sentence_emb(word2vec_list_query[0], word_vect))
empty_list = []
ques = []
#Removing empty values from data - empty values corresponds to titles with no proper details 
for ind,question in enumerate(word2vec_list):
    if question == []:
        empty_list.append(ind)
for inds,question in enumerate(Question_data_filtered):
    if inds not in empty_list:
        ques.append(question)
df_w2v = pd.DataFrame({'pos':ids_fil, 'en_ques':ques})
#Cosine Similarity
distances = scipy.spatial.distance.cdist([list(query_emb)], all_title_embeddings, "cosine")[0]
results = zip(range(len(distances)), distances)
results = sorted(results, key=lambda x: x[1])
#Top 5 Similar Question
for idx, distance in results[0:5]:
    index_val = [df_w2v[df_w2v['en_ques'] == ques[idx]]['pos']]
    df_v = pd.DataFrame({'Id': Wh_df_1[Wh_df_1.index.isin(index_val)]['Id'],'Title': Wh_df_1[Wh_df_1.index.isin(index_val)]['Title'],
                         'Score': 1-distance })
    df_res = df_res.append(df_v)
    print(ques[idx].strip(), "(Score: %.4f)" % (1-distance))
#dataframe to hold combined results of word2vec & bert findings
#Ranking the data based on the similarity score
df_res = df_res.reset_index(drop = True)   
df_res = df_res.sort_values(['Score'], ascending = False)
#If both model produce same question, then duplicate values are removed
dupl_val = df_res['Id'].duplicated()
df_res[~dupl_val]
# Out:
# which version of python do i have installed (Score: 0.9019)
# why python m venv myenv installs older version of pip into myenv than any version of pip i can find anywhere on the system (Score: 0.8874)
# which version of pip to use with my python installs (Score: 0.8613)
# where do i find the xml dom python package for the python and i have a suse x version of linux version (Score: 0.8544)
# which version of pydev should i install with python (Score: 0.8405)
#          Id                                              Title     Score
# 0   8917885       Which version of Python do I have installed?  0.943389
# 1  29458249  Which version of Pip to use with my Python ins...  0.931776
# 2  31678261  Where is a program that will let me execute Py...  0.925464
# 3   3049569  Where do I put utility functions in my Python ...  0.921216
# 4  17098004  which version of python is used when I run it ...  0.919910
# 6  29689514  Why 'python3 -m venv myenv' installs older ver...  0.887430
# 8   9027337  where do I find the xml.dom python package for...  0.854427
# 9  23300560  which version of pydev should I install with p...  0.840455

# %%
#Fetching Parent ID whose score is greater thaan 0.90
Parent_id = list(df_res[df_res['Score'] >= 0.90]['Id'])
Parent_id
# Out:
# [8917885, 29458249, 31678261, 3049569, 17098004, 8917885]

# %%
if len(Parent_id) == 0:
  print("Could you please add more information or be more specific, as we couldnt able to get similar matches for your question")

# %% [markdown]
# ## Answer Processing

# %% [markdown]
# ### Data Extraction

# %%
import pandas as pd
ans_main_df = pd.read_csv("./Answers.csv", encoding='latin-1')

# %% [markdown]
# **DATA PREPROCESSING**

# %%
#Finding tags present in the body tag
'''
from bs4 import BeautifulSoup
def tags(ans_text):
    soup = BeautifulSoup(ans_text, "html.parser")
    tags = [tag.name for tag in soup.find_all()]
    return tags
tags_uniq = []
tags_uniq.extend(ans_main_df['Body'].apply(tags))   
import itertools
tags_u = list(itertools.chain.from_iterable(tags_uniq))
set(tags_u)
'''
# Out:
# '\nfrom bs4 import BeautifulSoup\ndef tags(ans_text):\n    soup = BeautifulSoup(ans_text, "html.parser")\n    tags = [tag.name for tag in soup.find_all()]\n    return tags\ntags_uniq = []\ntags_uniq.extend(ans_main_df[\'Body\'].apply(tags))   \nimport itertools\ntags_u = list(itertools.chain.from_iterable(tags_uniq))\nset(tags_u)\n'

# %%
#Parse the HTML BODY of the answer corpus and remove the code,image & URL texts 
#Extract text part from Answer corpus
import re
from bs4 import BeautifulSoup
remove_tags = ['a','img','code']
req_tags = ['p','pre']
def code_img_url(text_data):
    soup = BeautifulSoup(text_data, "html.parser")
    for tag in soup.find_all(remove_tags):
        tag.decompose()
    para = ' '.join([tex.text for tex in soup.find_all(req_tags) if tex.text != "" ])
    return para

# %%
#Filter Answers for top similar question 
equi_ans = ans_main_df[ans_main_df['ParentId'].isin(Parent_id)]
equi_ans['Processed_body'] = equi_ans['Body'].apply(code_img_url) 
equi_ans
# Out:
#               Id  OwnerUserId          CreationDate  ParentId  Score  \
# 69358    3049575      34211.0  2010-06-15T22:36:48Z   3049569      4
# 69591    3058446     290340.0  2010-06-17T02:02:12Z   3049569      8
# 193393   8917907    1118101.0  2012-01-18T21:45:51Z   8917885    230
# 193394   8917909       4714.0  2012-01-18T21:45:52Z   8917885     73
# 193395   8917910        118.0  2012-01-18T21:45:54Z   8917885     22
# 193396   8917940     675637.0  2012-01-18T21:47:31Z   8917885     19
# 366142  17098298    1983854.0  2013-06-13T22:31:52Z  17098004      1
# 366147  17098416    1598412.0  2013-06-13T22:41:43Z  17098004      0
# 454252  20896732    3155933.0  2014-01-03T04:47:53Z   8917885     31
# 666378  29458415     707650.0  2015-04-05T14:37:45Z  29458249      2
# 666381  29458510    4751733.0  2015-04-05T14:49:15Z  29458249      1
# 689971  30283924    3446107.0  2015-05-17T06:13:30Z   8917885      3
# 697572  30556752    2099484.0  2015-05-31T11:17:35Z   8917885     11
# 729722  31678396    3646408.0  2015-07-28T13:55:05Z  31678261      0
# 729735  31678849    5099174.0  2015-07-28T14:10:57Z  31678261      0
# 792689  33838406    3790959.0  2015-11-21T00:47:48Z   8917885      6
# 812756  34511331    4507112.0  2015-12-29T12:42:55Z   8917885      1
# 839513  35387176    2418532.0  2016-02-14T00:56:43Z   8917885      3
# 903441  37462418    2527629.0  2016-05-26T13:34:19Z   8917885      4
# 935312  38520618      38749.0  2016-07-22T07:28:59Z   8917885      1
# 964888  39453410    6310523.0  2016-09-12T15:04:56Z   8917885      0
#
#                                                      Body  \
# 69358   <p>If you don't want to make it a member of th...
# 69591   <p><strong>Make it a static function...</stron...
# 193393  <pre><code>python -V\n</code></pre>\n\n<p><a h...
# 193394  <p>Python 2.5+:</p>\n\n<pre><code>python --ver...
# 193395  <p>At a command prompt type:</p>\n\n<pre><code...
# 193396  <p>When I open <code>Python (command line)</co...
# 366142  <p>To know which version is used by default, t...
# 366147  <pre><code>python --version\n</code></pre>\n\n...
# 454252  <p>in a Python IDE just copy and paste in the ...
# 666378  <ol>\n<li><p>Yes, it is safe. Python uses this...
# 666381  <p>No need to worried about if you have multip...
# 689971  <p>you can get version of python by using foll...
# 697572  <p>Although the question is "which version am ...
# 729722  <p>I am not sure what you are asking, a simple...
# 729735  <p>Once you go to your shell interface you mus...
# 792689  <pre><code>python -V\n</code></pre>\n\n<p>or <...
# 812756  <p>For me. open CMD and run\n        py\nit wi...
# 839513  <p>just start it at terminal</p>\n\n<pre><code...
# 903441  <pre><code>In [1]: import sys\n\nIn [2]: sys.v...
# 935312  <pre><code>&gt;&gt;&gt; import sys; print('{0[...
# 964888  <p>On Windows 10 with Python 3.6</p>\n\n<pre><...
#
#                                            Processed_body
# 69358   If you don't want to make it a member of the  ...
# 69591   Make it a static function... Your definition w...
# 193393          may also work (introduced in version 2.5)
# 193394                          Python 2.5+: Python 2.4-:
# 193395                          At a command prompt type:
# 193396  When I open  the first thing it tells me is th...
# 366142  To know which version is used by default, type...
# 366147  Then head on over to your .bashrc (should be i...
# 454252  in a Python IDE just copy and paste in the fol...
# 666378  Yes, it is safe. Python uses this naming like ...
# 666381  No need to worried about if you have multiple ...
# 689971  you can get version of python by using followi...
# 697572  Although the question is "which version am I u...
# 729722  I am not sure what you are asking, a simple go...
# 729735  Once you go to your shell interface you must e...
# 792689  or  NOTE :- Please note that the "V" in python...
# 812756  For me. open CMD and run\n        py\nit will ...
# 839513                          just start it at terminal
# 903441
# 935312                          so from the command line:
# 964888                      On Windows 10 with Python 3.6

# %%
#Data Preprocessing
Ans_body = list(equi_ans['Processed_body'])
Ans_data = list(simple_process(Ans_body))

# %%
#vectorizing 
#TF-IDF EMBEDDING 
Ans_data_filtered = [ ' '.join(ans) for ans in Ans_data if ans != [] ]
from sklearn.feature_extraction.text import TfidfVectorizer
vectorz = TfidfVectorizer()
tfidf_ans = vectorz.fit_transform(Ans_data_filtered)
#SVD decomposition to get dense vectors
from sklearn.decomposition import TruncatedSVD
tsvd = TruncatedSVD()
transformed = tsvd.fit_transform(tfidf_ans)

# %% [markdown]
# **Hierarchical Clustering**

# %%
ans_id = equi_ans[~(equi_ans['Processed_body'] == "")].index
import scipy.spatial.distance as distance
import scipy.cluster.hierarchy as hierarchy
D_tf = distance.pdist(transformed,'cosine')
L_tf= hierarchy.linkage(D_tf)
cls_tf = hierarchy.fcluster(L_tf,0.85,criterion = 'inconsistent')
df_cls_ans = pd.DataFrame({'pos':ans_id, 'Cluster_tf':cls_tf})
ans_final = pd.concat([equi_ans,df_cls_ans.set_index('pos')], axis = 1)
#Cluster results of tf-idf vectorized model
ans_final
# Out:
#               Id  OwnerUserId          CreationDate  ParentId  Score  \
# 69358    3049575      34211.0  2010-06-15T22:36:48Z   3049569      4
# 69591    3058446     290340.0  2010-06-17T02:02:12Z   3049569      8
# 193393   8917907    1118101.0  2012-01-18T21:45:51Z   8917885    230
# 193394   8917909       4714.0  2012-01-18T21:45:52Z   8917885     73
# 193395   8917910        118.0  2012-01-18T21:45:54Z   8917885     22
# 193396   8917940     675637.0  2012-01-18T21:47:31Z   8917885     19
# 366142  17098298    1983854.0  2013-06-13T22:31:52Z  17098004      1
# 366147  17098416    1598412.0  2013-06-13T22:41:43Z  17098004      0
# 454252  20896732    3155933.0  2014-01-03T04:47:53Z   8917885     31
# 666378  29458415     707650.0  2015-04-05T14:37:45Z  29458249      2
# 666381  29458510    4751733.0  2015-04-05T14:49:15Z  29458249      1
# 689971  30283924    3446107.0  2015-05-17T06:13:30Z   8917885      3
# 697572  30556752    2099484.0  2015-05-31T11:17:35Z   8917885     11
# 729722  31678396    3646408.0  2015-07-28T13:55:05Z  31678261      0
# 729735  31678849    5099174.0  2015-07-28T14:10:57Z  31678261      0
# 792689  33838406    3790959.0  2015-11-21T00:47:48Z   8917885      6
# 812756  34511331    4507112.0  2015-12-29T12:42:55Z   8917885      1
# 839513  35387176    2418532.0  2016-02-14T00:56:43Z   8917885      3
# 903441  37462418    2527629.0  2016-05-26T13:34:19Z   8917885      4
# 935312  38520618      38749.0  2016-07-22T07:28:59Z   8917885      1
# 964888  39453410    6310523.0  2016-09-12T15:04:56Z   8917885      0
#
#                                                      Body  \
# 69358   <p>If you don't want to make it a member of th...
# 69591   <p><strong>Make it a static function...</stron...
# 193393  <pre><code>python -V\n</code></pre>\n\n<p><a h...
# 193394  <p>Python 2.5+:</p>\n\n<pre><code>python --ver...
# 193395  <p>At a command prompt type:</p>\n\n<pre><code...
# 193396  <p>When I open <code>Python (command line)</co...
# 366142  <p>To know which version is used by default, t...
# 366147  <pre><code>python --version\n</code></pre>\n\n...
# 454252  <p>in a Python IDE just copy and paste in the ...
# 666378  <ol>\n<li><p>Yes, it is safe. Python uses this...
# 666381  <p>No need to worried about if you have multip...
# 689971  <p>you can get version of python by using foll...
# 697572  <p>Although the question is "which version am ...
# 729722  <p>I am not sure what you are asking, a simple...
# 729735  <p>Once you go to your shell interface you mus...
# 792689  <pre><code>python -V\n</code></pre>\n\n<p>or <...
# 812756  <p>For me. open CMD and run\n        py\nit wi...
# 839513  <p>just start it at terminal</p>\n\n<pre><code...
# 903441  <pre><code>In [1]: import sys\n\nIn [2]: sys.v...
# 935312  <pre><code>&gt;&gt;&gt; import sys; print('{0[...
# 964888  <p>On Windows 10 with Python 3.6</p>\n\n<pre><...
#
#                                            Processed_body  Cluster_tf
# 69358   If you don't want to make it a member of the  ...         5.0
# 69591   Make it a static function... Your definition w...         4.0
# 193393          may also work (introduced in version 2.5)         2.0
# 193394                          Python 2.5+: Python 2.4-:         1.0
# 193395                          At a command prompt type:         5.0
# 193396  When I open  the first thing it tells me is th...         4.0
# 366142  To know which version is used by default, type...         4.0
# 366147  Then head on over to your .bashrc (should be i...         4.0
# 454252  in a Python IDE just copy and paste in the fol...         3.0
# 666378  Yes, it is safe. Python uses this naming like ...         3.0
# 666381  No need to worried about if you have multiple ...         2.0
# 689971  you can get version of python by using followi...         2.0
# 697572  Although the question is "which version am I u...         4.0
# 729722  I am not sure what you are asking, a simple go...         4.0
# 729735  Once you go to your shell interface you must e...         4.0
# 792689  or  NOTE :- Please note that the "V" in python...         1.0
# 812756  For me. open CMD and run\n        py\nit will ...         3.0
# 839513                          just start it at terminal         5.0
# 903441                                                            NaN
# 935312                          so from the command line:         5.0
# 964888                      On Windows 10 with Python 3.6         1.0

# %%
#Word2vec Embedding
#Data Preprocessing
word2vec_list_ans = [unseen_words(question) for question in Ans_data ]
all_ans_embeddings = []
for ans in word2vec_list_ans:
    if ans != []:
        list_val = list(sentence_emb(ans, word_vect))
        all_ans_embeddings.append(list_val)
#Clustering 
D1_ans = distance.pdist(all_ans_embeddings,'cosine')
L1_ans= hierarchy.linkage(D1_ans)
cls1_ans = hierarchy.fcluster(L1_ans,0.85,criterion = 'inconsistent')
df_cls_w2v_ans = pd.DataFrame({'pos':ans_id, 'Cluster_w2v':cls1_ans})
ans_final = pd.concat([ans_final,df_cls_w2v_ans.set_index('pos')], axis = 1)
#Cluster results of word2vec vectorized model
ans_final
# Out:
#               Id  OwnerUserId          CreationDate  ParentId  Score  \
# 69358    3049575      34211.0  2010-06-15T22:36:48Z   3049569      4
# 69591    3058446     290340.0  2010-06-17T02:02:12Z   3049569      8
# 193393   8917907    1118101.0  2012-01-18T21:45:51Z   8917885    230
# 193394   8917909       4714.0  2012-01-18T21:45:52Z   8917885     73
# 193395   8917910        118.0  2012-01-18T21:45:54Z   8917885     22
# 193396   8917940     675637.0  2012-01-18T21:47:31Z   8917885     19
# 366142  17098298    1983854.0  2013-06-13T22:31:52Z  17098004      1
# 366147  17098416    1598412.0  2013-06-13T22:41:43Z  17098004      0
# 454252  20896732    3155933.0  2014-01-03T04:47:53Z   8917885     31
# 666378  29458415     707650.0  2015-04-05T14:37:45Z  29458249      2
# 666381  29458510    4751733.0  2015-04-05T14:49:15Z  29458249      1
# 689971  30283924    3446107.0  2015-05-17T06:13:30Z   8917885      3
# 697572  30556752    2099484.0  2015-05-31T11:17:35Z   8917885     11
# 729722  31678396    3646408.0  2015-07-28T13:55:05Z  31678261      0
# 729735  31678849    5099174.0  2015-07-28T14:10:57Z  31678261      0
# 792689  33838406    3790959.0  2015-11-21T00:47:48Z   8917885      6
# 812756  34511331    4507112.0  2015-12-29T12:42:55Z   8917885      1
# 839513  35387176    2418532.0  2016-02-14T00:56:43Z   8917885      3
# 903441  37462418    2527629.0  2016-05-26T13:34:19Z   8917885      4
# 935312  38520618      38749.0  2016-07-22T07:28:59Z   8917885      1
# 964888  39453410    6310523.0  2016-09-12T15:04:56Z   8917885      0
#
#                                                      Body  \
# 69358   <p>If you don't want to make it a member of th...
# 69591   <p><strong>Make it a static function...</stron...
# 193393  <pre><code>python -V\n</code></pre>\n\n<p><a h...
# 193394  <p>Python 2.5+:</p>\n\n<pre><code>python --ver...
# 193395  <p>At a command prompt type:</p>\n\n<pre><code...
# 193396  <p>When I open <code>Python (command line)</co...
# 366142  <p>To know which version is used by default, t...
# 366147  <pre><code>python --version\n</code></pre>\n\n...
# 454252  <p>in a Python IDE just copy and paste in the ...
# 666378  <ol>\n<li><p>Yes, it is safe. Python uses this...
# 666381  <p>No need to worried about if you have multip...
# 689971  <p>you can get version of python by using foll...
# 697572  <p>Although the question is "which version am ...
# 729722  <p>I am not sure what you are asking, a simple...
# 729735  <p>Once you go to your shell interface you mus...
# 792689  <pre><code>python -V\n</code></pre>\n\n<p>or <...
# 812756  <p>For me. open CMD and run\n        py\nit wi...
# 839513  <p>just start it at terminal</p>\n\n<pre><code...
# 903441  <pre><code>In [1]: import sys\n\nIn [2]: sys.v...
# 935312  <pre><code>&gt;&gt;&gt; import sys; print('{0[...
# 964888  <p>On Windows 10 with Python 3.6</p>\n\n<pre><...
#
#                                            Processed_body  Cluster_tf  \
# 69358   If you don't want to make it a member of the  ...         5.0
# 69591   Make it a static function... Your definition w...         4.0
# 193393          may also work (introduced in version 2.5)         2.0
# 193394                          Python 2.5+: Python 2.4-:         1.0
# 193395                          At a command prompt type:         5.0
# 193396  When I open  the first thing it tells me is th...         4.0
# 366142  To know which version is used by default, type...         4.0
# 366147  Then head on over to your .bashrc (should be i...         4.0
# 454252  in a Python IDE just copy and paste in the fol...         3.0
# 666378  Yes, it is safe. Python uses this naming like ...         3.0
# 666381  No need to worried about if you have multiple ...         2.0
# 689971  you can get version of python by using followi...         2.0
# 697572  Although the question is "which version am I u...         4.0
# 729722  I am not sure what you are asking, a simple go...         4.0
# 729735  Once you go to your shell interface you must e...         4.0
# 792689  or  NOTE :- Please note that the "V" in python...         1.0
# 812756  For me. open CMD and run\n        py\nit will ...         3.0
# 839513                          just start it at terminal         5.0
# 903441                                                            NaN
# 935312                          so from the command line:         5.0
# 964888                      On Windows 10 with Python 3.6         1.0
#
#         Cluster_w2v
# 69358           3.0
# 69591           3.0
# 193393          3.0
# 193394          1.0
# 193395          2.0
# 193396          4.0
# 366142          3.0
# 366147          3.0
# 454252          3.0
# 666378          3.0
# 666381          3.0
# 689971          3.0
# 697572          3.0
# 729722          3.0
# 729735          3.0
# 792689          3.0
# 812756          3.0
# 839513          3.0
# 903441          NaN
# 935312          2.0
# 964888          1.0

# %%
#Bert Embedding 
#Encoding the data
Ans_embeddings = embedder.encode(Ans_data_filtered)
D_bert_ans = distance.pdist(Ans_embeddings,'cosine')
L_bert_ans= hierarchy.linkage(D_bert_ans)
cls_bert_ans = hierarchy.fcluster(L_bert_ans,0.85,criterion = 'inconsistent')
df_cls_bert_Ans = pd.DataFrame({'pos':ans_id, 'Cluster_bert':cls_bert_ans})
ans_final = pd.concat([ans_final,df_cls_bert_Ans.set_index('pos')], axis = 1)
#Cluster results 
ans_final
# Out:
#               Id  OwnerUserId          CreationDate  ParentId  Score  \
# 69358    3049575      34211.0  2010-06-15T22:36:48Z   3049569      4
# 69591    3058446     290340.0  2010-06-17T02:02:12Z   3049569      8
# 193393   8917907    1118101.0  2012-01-18T21:45:51Z   8917885    230
# 193394   8917909       4714.0  2012-01-18T21:45:52Z   8917885     73
# 193395   8917910        118.0  2012-01-18T21:45:54Z   8917885     22
# 193396   8917940     675637.0  2012-01-18T21:47:31Z   8917885     19
# 366142  17098298    1983854.0  2013-06-13T22:31:52Z  17098004      1
# 366147  17098416    1598412.0  2013-06-13T22:41:43Z  17098004      0
# 454252  20896732    3155933.0  2014-01-03T04:47:53Z   8917885     31
# 666378  29458415     707650.0  2015-04-05T14:37:45Z  29458249      2
# 666381  29458510    4751733.0  2015-04-05T14:49:15Z  29458249      1
# 689971  30283924    3446107.0  2015-05-17T06:13:30Z   8917885      3
# 697572  30556752    2099484.0  2015-05-31T11:17:35Z   8917885     11
# 729722  31678396    3646408.0  2015-07-28T13:55:05Z  31678261      0
# 729735  31678849    5099174.0  2015-07-28T14:10:57Z  31678261      0
# 792689  33838406    3790959.0  2015-11-21T00:47:48Z   8917885      6
# 812756  34511331    4507112.0  2015-12-29T12:42:55Z   8917885      1
# 839513  35387176    2418532.0  2016-02-14T00:56:43Z   8917885      3
# 903441  37462418    2527629.0  2016-05-26T13:34:19Z   8917885      4
# 935312  38520618      38749.0  2016-07-22T07:28:59Z   8917885      1
# 964888  39453410    6310523.0  2016-09-12T15:04:56Z   8917885      0
#
#                                                      Body  \
# 69358   <p>If you don't want to make it a member of th...
# 69591   <p><strong>Make it a static function...</stron...
# 193393  <pre><code>python -V\n</code></pre>\n\n<p><a h...
# 193394  <p>Python 2.5+:</p>\n\n<pre><code>python --ver...
# 193395  <p>At a command prompt type:</p>\n\n<pre><code...
# 193396  <p>When I open <code>Python (command line)</co...
# 366142  <p>To know which version is used by default, t...
# 366147  <pre><code>python --version\n</code></pre>\n\n...
# 454252  <p>in a Python IDE just copy and paste in the ...
# 666378  <ol>\n<li><p>Yes, it is safe. Python uses this...
# 666381  <p>No need to worried about if you have multip...
# 689971  <p>you can get version of python by using foll...
# 697572  <p>Although the question is "which version am ...
# 729722  <p>I am not sure what you are asking, a simple...
# 729735  <p>Once you go to your shell interface you mus...
# 792689  <pre><code>python -V\n</code></pre>\n\n<p>or <...
# 812756  <p>For me. open CMD and run\n        py\nit wi...
# 839513  <p>just start it at terminal</p>\n\n<pre><code...
# 903441  <pre><code>In [1]: import sys\n\nIn [2]: sys.v...
# 935312  <pre><code>&gt;&gt;&gt; import sys; print('{0[...
# 964888  <p>On Windows 10 with Python 3.6</p>\n\n<pre><...
#
#                                            Processed_body  Cluster_tf  \
# 69358   If you don't want to make it a member of the  ...         5.0
# 69591   Make it a static function... Your definition w...         4.0
# 193393          may also work (introduced in version 2.5)         2.0
# 193394                          Python 2.5+: Python 2.4-:         1.0
# 193395                          At a command prompt type:         5.0
# 193396  When I open  the first thing it tells me is th...         4.0
# 366142  To know which version is used by default, type...         4.0
# 366147  Then head on over to your .bashrc (should be i...         4.0
# 454252  in a Python IDE just copy and paste in the fol...         3.0
# 666378  Yes, it is safe. Python uses this naming like ...         3.0
# 666381  No need to worried about if you have multiple ...         2.0
# 689971  you can get version of python by using followi...         2.0
# 697572  Although the question is "which version am I u...         4.0
# 729722  I am not sure what you are asking, a simple go...         4.0
# 729735  Once you go to your shell interface you must e...         4.0
# 792689  or  NOTE :- Please note that the "V" in python...         1.0
# 812756  For me. open CMD and run\n        py\nit will ...         3.0
# 839513                          just start it at terminal         5.0
# 903441                                                            NaN
# 935312                          so from the command line:         5.0
# 964888                      On Windows 10 with Python 3.6         1.0
#
#         Cluster_w2v  Cluster_bert
# 69358           3.0          11.0
# 69591           3.0           4.0
# 193393          3.0          11.0
# 193394          1.0           2.0
# 193395          2.0           1.0
# 193396          4.0           1.0
# 366142          3.0           8.0
# 366147          3.0          10.0
# 454252          3.0           3.0
# 666378          3.0           4.0
# 666381          3.0           4.0
# 689971          3.0           3.0
# 697572          3.0           7.0
# 729722          3.0           6.0
# 729735          3.0           4.0
# 792689          3.0           9.0
# 812756          3.0           5.0
# 839513          3.0           1.0
# 903441          NaN           NaN
# 935312          2.0           1.0
# 964888          1.0           2.0

# %% [markdown]
# All the cluster values are manually evaluated for various search question, we could see bert embedded model produces best result

# %%
ans_final = ans_final[['Id', 'OwnerUserId', 'CreationDate', 'ParentId', 'Score', 'Body',
       'Processed_body','Cluster_bert']]

# %% [markdown]
# ## Question and Answer Relevance Mapping

# %%
#Cosine Similarity between query and answer corpus
df_ans = pd.DataFrame()
import scipy.spatial
distances_ans = scipy.spatial.distance.cdist([list(query_embedding[0])], Ans_embeddings, "cosine")[0]
df_cls_bert_Ans_ques = pd.DataFrame({'pos':ans_id, 'Similarity_Score':distances_ans})
ans_final = pd.concat([ans_final,df_cls_bert_Ans_ques.set_index('pos')], axis = 1)
ans_final = ans_final.dropna()
ans_final
# Out:
#               Id  OwnerUserId          CreationDate  ParentId  Score  \
# 69358    3049575      34211.0  2010-06-15T22:36:48Z   3049569      4
# 69591    3058446     290340.0  2010-06-17T02:02:12Z   3049569      8
# 193393   8917907    1118101.0  2012-01-18T21:45:51Z   8917885    230
# 193394   8917909       4714.0  2012-01-18T21:45:52Z   8917885     73
# 193395   8917910        118.0  2012-01-18T21:45:54Z   8917885     22
# 193396   8917940     675637.0  2012-01-18T21:47:31Z   8917885     19
# 366142  17098298    1983854.0  2013-06-13T22:31:52Z  17098004      1
# 366147  17098416    1598412.0  2013-06-13T22:41:43Z  17098004      0
# 454252  20896732    3155933.0  2014-01-03T04:47:53Z   8917885     31
# 666378  29458415     707650.0  2015-04-05T14:37:45Z  29458249      2
# 666381  29458510    4751733.0  2015-04-05T14:49:15Z  29458249      1
# 689971  30283924    3446107.0  2015-05-17T06:13:30Z   8917885      3
# 697572  30556752    2099484.0  2015-05-31T11:17:35Z   8917885     11
# 729722  31678396    3646408.0  2015-07-28T13:55:05Z  31678261      0
# 729735  31678849    5099174.0  2015-07-28T14:10:57Z  31678261      0
# 792689  33838406    3790959.0  2015-11-21T00:47:48Z   8917885      6
# 812756  34511331    4507112.0  2015-12-29T12:42:55Z   8917885      1
# 839513  35387176    2418532.0  2016-02-14T00:56:43Z   8917885      3
# 935312  38520618      38749.0  2016-07-22T07:28:59Z   8917885      1
# 964888  39453410    6310523.0  2016-09-12T15:04:56Z   8917885      0
#
#                                                      Body  \
# 69358   <p>If you don't want to make it a member of th...
# 69591   <p><strong>Make it a static function...</stron...
# 193393  <pre><code>python -V\n</code></pre>\n\n<p><a h...
# 193394  <p>Python 2.5+:</p>\n\n<pre><code>python --ver...
# 193395  <p>At a command prompt type:</p>\n\n<pre><code...
# 193396  <p>When I open <code>Python (command line)</co...
# 366142  <p>To know which version is used by default, t...
# 366147  <pre><code>python --version\n</code></pre>\n\n...
# 454252  <p>in a Python IDE just copy and paste in the ...
# 666378  <ol>\n<li><p>Yes, it is safe. Python uses this...
# 666381  <p>No need to worried about if you have multip...
# 689971  <p>you can get version of python by using foll...
# 697572  <p>Although the question is "which version am ...
# 729722  <p>I am not sure what you are asking, a simple...
# 729735  <p>Once you go to your shell interface you mus...
# 792689  <pre><code>python -V\n</code></pre>\n\n<p>or <...
# 812756  <p>For me. open CMD and run\n        py\nit wi...
# 839513  <p>just start it at terminal</p>\n\n<pre><code...
# 935312  <pre><code>&gt;&gt;&gt; import sys; print('{0[...
# 964888  <p>On Windows 10 with Python 3.6</p>\n\n<pre><...
#
#                                            Processed_body  Cluster_bert  \
# 69358   If you don't want to make it a member of the  ...          11.0
# 69591   Make it a static function... Your definition w...           4.0
# 193393          may also work (introduced in version 2.5)          11.0
# 193394                          Python 2.5+: Python 2.4-:           2.0
# 193395                          At a command prompt type:           1.0
# 193396  When I open  the first thing it tells me is th...           1.0
# 366142  To know which version is used by default, type...           8.0
# 366147  Then head on over to your .bashrc (should be i...          10.0
# 454252  in a Python IDE just copy and paste in the fol...           3.0
# 666378  Yes, it is safe. Python uses this naming like ...           4.0
# 666381  No need to worried about if you have multiple ...           4.0
# 689971  you can get version of python by using followi...           3.0
# 697572  Although the question is "which version am I u...           7.0
# 729722  I am not sure what you are asking, a simple go...           6.0
# 729735  Once you go to your shell interface you must e...           4.0
# 792689  or  NOTE :- Please note that the "V" in python...           9.0
# 812756  For me. open CMD and run\n        py\nit will ...           5.0
# 839513                          just start it at terminal           1.0
# 935312                          so from the command line:           1.0
# 964888                      On Windows 10 with Python 3.6           2.0
#
#         Similarity_Score
# 69358           0.577834
# 69591           0.327658
# 193393          0.670012
# 193394          0.290339
# 193395          0.640489
# 193396          0.667392
# 366142          0.416672
# 366147          0.490607
# 454252          0.170300
# 666378          0.240963
# 666381          0.299447
# 689971          0.183076
# 697572          0.366153
# 729722          0.313341
# 729735          0.255999
# 792689          0.318808
# 812756          0.267977
# 839513          0.725951
# 935312          0.755936
# 964888          0.259685

# %%
#Aggregating the scores to get combined results for each of the cluster values
agg_val = {}
agg_val['Score'] = 'sum'
agg_val['Cluster_bert'] = 'first' 
agg_val['Similarity_Score'] = 'mean'
Clus_score = ans_final[['Score','Cluster_bert','Similarity_Score']].groupby('Cluster_bert').agg(agg_val)
Clus_score = Clus_score.reset_index(drop = True)
print(Clus_score)
# Out:
#     Score  Cluster_bert  Similarity_Score
# 0      45           1.0          0.697442
# 1      73           2.0          0.275012
# 2      34           3.0          0.176688
# 3      11           4.0          0.281017
# 4       1           5.0          0.267977
# 5       0           6.0          0.313341
# 6      11           7.0          0.366153
# 7       1           8.0          0.416672
# 8       6           9.0          0.318808
# 9       0          10.0          0.490607
# 10    234          11.0          0.623923

# %%
#Ranking methodalogy - score * similarity score
#As majority of the answer part contains code chunks, leaving less information in natural text to get actual relevance. 
#To overcome this issue, we made use of the score feature available in answer.csv. 
#Score value is the user annotated score for each answer to the question. 
#We combined both similarity scores and this score value to get an overall score for each cluster. 
#Clusters with maximum score are ranked as top answer output. 
Ranking_score_bert = Clus_score['Score'] * Clus_score['Similarity_Score']
Clus_score['Ranking_score_bert'] = Ranking_score_bert
Clus_score_bert = Clus_score.sort_values(['Ranking_score_bert'], ascending = False)
id_ans_bert = list(ans_final[ans_final['Cluster_bert'] == Clus_score_bert['Cluster_bert'].iloc[0]]['Id'])

# %%
#Top Ranked Cluster results
Top_answers_bert = ans_main_df[ans_main_df['Id'].isin(id_ans_bert) ]
Top_answers_bert = Top_answers_bert.sort_values(['Score'], ascending = False)
Top_answers_bert
# Out:
#              Id  OwnerUserId          CreationDate  ParentId  Score  \
# 193393  8917907    1118101.0  2012-01-18T21:45:51Z   8917885    230
# 69358   3049575      34211.0  2010-06-15T22:36:48Z   3049569      4
#
#                                                      Body
# 193393  <pre><code>python -V\n</code></pre>\n\n<p><a h...
# 69358   <p>If you don't want to make it a member of th...

# %%
#Expanded version of Top Answers
for text in Top_answers_bert['Body']:
    soup = BeautifulSoup(text, "html.parser")
    para = ' '.join([tex.text for tex in soup.find_all()])
    print(para)
# Out:
# python -V
#  python -V
#  http://docs.python.org/using/cmdline.html#generic-options http://docs.python.org/using/cmdline.html#generic-options --version may also work (introduced in version 2.5) --version
# If you don't want to make it a member of the Table class you could put it into a utilities module. Table utilities

# %% [markdown]
# **Future Scope:**
#
# ●	Extend research for other question pairs apart from WH-questions.
#
# ●	Build models that represent the entire Stack Overflow corpus having various programming domain-specific results.
#
# ●	Build an interactive Q&A search engine and related  API for wider use.
